# %%
# !pip install pyTigerGraph

# %% [markdown]
# ## Connect to Solution

# %%
import pyTigerGraph as tg
import json

hostName = "https://northwind.i.tgcloud.io"
userName = "tigergraph"
password = "tigergraph"

conn = tg.TigerGraphConnection(host=hostName, username=userName, password=password)

print("Connected")
# Out:
# Connected

# %% [markdown]
# # Create Schema

# %% [markdown]
# ## Create Vertices

# %%
conn.gsql('''
CREATE VERTEX Shipper(PRIMARY_ID id INT) WITH STATS="OUTDEGREE_BY_EDGETYPE", PRIMARY_ID_AS_ATTRIBUTE="true"
CREATE VERTEX Employee(PRIMARY_ID id INT, lastName STRING, firstName STRING, birthDate DATETIME, hireDate DATETIME, photoPath STRING, salary FLOAT, notes STRING) WITH STATS="OUTDEGREE_BY_EDGETYPE", PRIMARY_ID_AS_ATTRIBUTE="true"
CREATE VERTEX City(PRIMARY_ID id STRING) WITH STATS="OUTDEGREE_BY_EDGETYPE", PRIMARY_ID_AS_ATTRIBUTE="true"
CREATE VERTEX Region(PRIMARY_ID id STRING, description STRING) WITH STATS="OUTDEGREE_BY_EDGETYPE", PRIMARY_ID_AS_ATTRIBUTE="true"
CREATE VERTEX PostalCode(PRIMARY_ID id STRING) WITH STATS="OUTDEGREE_BY_EDGETYPE", PRIMARY_ID_AS_ATTRIBUTE="true"
CREATE VERTEX Country(PRIMARY_ID id STRING) WITH STATS="OUTDEGREE_BY_EDGETYPE", PRIMARY_ID_AS_ATTRIBUTE="true"
CREATE VERTEX Territory(PRIMARY_ID id STRING, description STRING) WITH STATS="OUTDEGREE_BY_EDGETYPE", PRIMARY_ID_AS_ATTRIBUTE="true"
CREATE VERTEX CustomerOrder(PRIMARY_ID id INT, orderDate DATETIME, requiredDate DATETIME, shippedDate DATETIME, shipVia INT, freight STRING, shipName STRING) WITH STATS="OUTDEGREE_BY_EDGETYPE", PRIMARY_ID_AS_ATTRIBUTE="true"
CREATE VERTEX Address(PRIMARY_ID id STRING) WITH STATS="OUTDEGREE_BY_EDGETYPE", PRIMARY_ID_AS_ATTRIBUTE="true"
CREATE VERTEX Title(PRIMARY_ID id STRING) WITH STATS="OUTDEGREE_BY_EDGETYPE", PRIMARY_ID_AS_ATTRIBUTE="true"
CREATE VERTEX TitleOfCourtesy(PRIMARY_ID id STRING) WITH STATS="OUTDEGREE_BY_EDGETYPE", PRIMARY_ID_AS_ATTRIBUTE="true"
CREATE VERTEX Customer(PRIMARY_ID id STRING, contactName STRING, contactTitle STRING) WITH STATS="OUTDEGREE_BY_EDGETYPE", PRIMARY_ID_AS_ATTRIBUTE="true"
CREATE VERTEX Phone(PRIMARY_ID id STRING, extension STRING) WITH STATS="OUTDEGREE_BY_EDGETYPE", PRIMARY_ID_AS_ATTRIBUTE="true"
CREATE VERTEX Fax(PRIMARY_ID id STRING) WITH STATS="OUTDEGREE_BY_EDGETYPE"
CREATE VERTEX Product(PRIMARY_ID id INT, productName STRING, qtyPerUnit STRING, unitPrice FLOAT, inStock INT, onOrder INT, reorderLevel INT, discontinued BOOL) WITH STATS="OUTDEGREE_BY_EDGETYPE", PRIMARY_ID_AS_ATTRIBUTE="true"
CREATE VERTEX Category(PRIMARY_ID id INT, name STRING, description STRING) WITH STATS="OUTDEGREE_BY_EDGETYPE", PRIMARY_ID_AS_ATTRIBUTE="true"
CREATE VERTEX Company(PRIMARY_ID id STRING) WITH STATS="OUTDEGREE_BY_EDGETYPE", PRIMARY_ID_AS_ATTRIBUTE="true"
CREATE VERTEX CustomerType(PRIMARY_ID id STRING, customerDescription STRING) WITH STATS="OUTDEGREE_BY_EDGETYPE", PRIMARY_ID_AS_ATTRIBUTE="true"
CREATE VERTEX Supplier(PRIMARY_ID id INT, contactName STRING, contactTitle STRING, homePage STRING) WITH STATS="OUTDEGREE_BY_EDGETYPE", PRIMARY_ID_AS_ATTRIBUTE="true"
''')

# %% [markdown]
# ## Create Edges

# %%
conn.gsql('''
CREATE DIRECTED EDGE reports_to(FROM Employee, TO Employee) WITH REVERSE_EDGE="reverse_reports_to"
CREATE UNDIRECTED EDGE in_territory(FROM Employee, TO Territory)
CREATE UNDIRECTED EDGE to_region(FROM CustomerOrder, TO Region)
CREATE UNDIRECTED EDGE to_country(FROM CustomerOrder, TO Country)
CREATE UNDIRECTED EDGE to_postal_code(FROM CustomerOrder, TO PostalCode)
CREATE UNDIRECTED EDGE to_city(FROM CustomerOrder, TO City)
CREATE UNDIRECTED EDGE to_address(FROM CustomerOrder, TO Address)
CREATE UNDIRECTED EDGE has_title(FROM Employee, TO Title)
CREATE UNDIRECTED EDGE has_toc(FROM Employee, TO TitleOfCourtesy)
CREATE UNDIRECTED EDGE placed_order(FROM Customer, TO CustomerOrder, orderDate DATETIME)
CREATE UNDIRECTED EDGE is_category(FROM Product, TO Category)
CREATE UNDIRECTED EDGE contains_product(FROM CustomerOrder, TO Product, unitPrice FLOAT, quantity INT, discount DOUBLE)
CREATE UNDIRECTED EDGE ship_via(FROM CustomerOrder, TO Shipper)
CREATE UNDIRECTED EDGE is_type(FROM Customer, TO CustomerType)
CREATE UNDIRECTED EDGE in_city(FROM Employee, TO City|FROM Customer, TO City|FROM Supplier, TO City)
CREATE UNDIRECTED EDGE in_region(FROM Territory, TO Region|FROM Employee, TO Region|FROM Customer, TO Region|FROM Supplier, TO Region)
CREATE UNDIRECTED EDGE in_postal_code(FROM Employee, TO PostalCode|FROM Customer, TO PostalCode|FROM Supplier, TO PostalCode)
CREATE UNDIRECTED EDGE in_country(FROM Employee, TO Country|FROM Customer, TO Country|FROM Supplier, TO Country)
CREATE UNDIRECTED EDGE at_address(FROM Employee, TO Address|FROM Customer, TO Address|FROM Supplier, TO Address)
CREATE UNDIRECTED EDGE has_fax(FROM Customer, TO Fax|FROM Supplier, TO Fax)
CREATE UNDIRECTED EDGE has_phone(FROM Employee, TO Phone|FROM Customer, TO Phone|FROM Shipper, TO Phone|FROM Supplier, TO Phone)
CREATE UNDIRECTED EDGE from_company(FROM Shipper, TO Company|FROM Supplier, TO Company)
CREATE UNDIRECTED EDGE from_supplier(FROM Product, TO Supplier)
CREATE UNDIRECTED EDGE facilitated_order(FROM CustomerOrder, TO Employee)
''')

# %% [markdown]
# ## Create Graph

# %%
conn.gsql('''
    CREATE GRAPH Northwind(Shipper, Employee, City, Region, PostalCode, Country, Territory, CustomerOrder, Address,
      Title, TitleOfCourtesy, Customer, Phone, Fax, Product, Category, Company, CustomerType, Supplier, reports_to, in_territory,
      to_region, to_country, to_postal_code, to_city, to_address, has_title, has_toc, placed_order, is_category, contains_product,
      ship_via, is_type, in_city, in_region, in_postal_code, in_country, at_address, has_fax, has_phone, from_company, from_supplier, facilitated_order)
''')

# %% [markdown]
# # Connect to Graph

# %%
graphName = "Northwind"
conn.graphname = graphName
secret = conn.createSecret()
token = conn.getToken(secret, setToken=True)[0]

print(token)

# connect to graph with token
conn = tg.TigerGraphConnection(host=hostName, username=userName, password=password, graphname=graphName, apiToken=token)
# Out:
# pi4ocevfj8t448plc9knc8lqp1f0deea

# %% [markdown]
# # Load Data

# %% [markdown]
# ## Create Loading Jobs

# %%
results = conn.gsql('''
USE GRAPH Northwind
BEGIN
CREATE LOADING JOB load_job_categories FOR GRAPH Northwind {
      DEFINE FILENAME MyDataSource;
      LOAD MyDataSource TO VERTEX Category VALUES($0, $1, $2) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
    }
END
''')

# %%
results = conn.gsql('''
USE GRAPH Northwind
BEGIN
CREATE LOADING JOB load_job_customers FOR GRAPH Northwind {
      DEFINE FILENAME MyDataSource;
      LOAD MyDataSource TO VERTEX Customer VALUES($0, $2, $3) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE has_phone VALUES($0 Customer, $9 Phone) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE at_address VALUES($0 Customer, $4 Address) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE in_region VALUES($0 Customer, $6 Region) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE in_country VALUES($0 Customer, $8 Country) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE in_postal_code VALUES($0 Customer, $7 PostalCode) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE in_city VALUES($0 Customer, $5 City) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE has_fax VALUES($0 Customer, $10 Fax) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
    }
END
''')

# %%
results = conn.gsql('''
USE GRAPH Northwind
BEGIN
CREATE LOADING JOB load_job_employee_territories FOR GRAPH Northwind {
      DEFINE FILENAME MyDataSource;
      LOAD MyDataSource TO EDGE in_territory VALUES($0, $1) USING SEPARATOR="|", HEADER="true", EOL="\n";
    }
END
''')

# %%
results = conn.gsql('''
USE GRAPH Northwind
BEGIN
CREATE LOADING JOB load_job_order_details FOR GRAPH Northwind {
      DEFINE FILENAME MyDataSource;
      LOAD MyDataSource TO EDGE contains_product VALUES($0, $1, $2, $3, $4) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
    }
END
''')

# %%
results = conn.gsql('''
USE GRAPH Northwind
BEGIN
CREATE LOADING JOB load_job_employees FOR GRAPH Northwind {
      DEFINE FILENAME MyDataSource;
      LOAD MyDataSource TO VERTEX Employee VALUES($0, $1, $2, $5, $6, $17, _, $15) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE reports_to VALUES($0, $16) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE has_toc VALUES($0, $4) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE has_title VALUES($0, $3) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE has_phone VALUES($0 Employee, $12 Phone) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE at_address VALUES($0 Employee, $7 Address) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE in_region VALUES($0 Employee, $9 Region) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE in_country VALUES($0 Employee, $11 Country) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE in_postal_code VALUES($0 Employee, $10 PostalCode) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE in_city VALUES($0 Employee, $8 City) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
    }
END
''')

# %%
results = conn.gsql('''
USE GRAPH Northwind
BEGIN
CREATE LOADING JOB load_job_orders FOR GRAPH Northwind {
      DEFINE FILENAME MyDataSource;
      LOAD MyDataSource TO VERTEX CustomerOrder VALUES($0, $3, $4, $5, $6, $7, $8) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE placed_order VALUES($1, $0, $3) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE ship_via VALUES($0, $6) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE to_city VALUES($0, $10) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE to_postal_code VALUES($0, $12) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE to_country VALUES($0, $13) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE to_region VALUES($0, $11) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE to_address VALUES($0, $9) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE facilitated_order VALUES($0, $2) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
    }
END
''')

# %%
results = conn.gsql('''
USE GRAPH Northwind
BEGIN
CREATE LOADING JOB load_job_products FOR GRAPH Northwind {
      DEFINE FILENAME MyDataSource;
      LOAD MyDataSource TO VERTEX Product VALUES($0, $1, $4, $5, $6, $7, $8, $9) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE is_category VALUES($0, $3) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE from_supplier VALUES($0, $2) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
    }
END
''')

# %%
results = conn.gsql('''
USE GRAPH Northwind
BEGIN
CREATE LOADING JOB load_job_regions FOR GRAPH Northwind {
      DEFINE FILENAME MyDataSource;
      LOAD MyDataSource TO VERTEX Region VALUES($0, $1) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
    }
END
''')

# %%
results = conn.gsql('''
USE GRAPH Northwind
BEGIN
CREATE LOADING JOB load_job_shippers FOR GRAPH Northwind {
      DEFINE FILENAME MyDataSource;
      LOAD MyDataSource TO EDGE from_company VALUES($0 Shipper, $1 Company) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE has_phone VALUES($0 Shipper, $2 Phone) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
    }
END
''')

# %%
results = conn.gsql('''
USE GRAPH Northwind
BEGIN
CREATE LOADING JOB load_job_suppliers FOR GRAPH Northwind {
      DEFINE FILENAME MyDataSource;
      LOAD MyDataSource TO VERTEX Supplier VALUES($0, $2, $3, $11) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE has_fax VALUES($0 Supplier, $10 Fax) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE in_city VALUES($0 Supplier, $5 City) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE in_postal_code VALUES($0 Supplier, $7 PostalCode) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE in_country VALUES($0 Supplier, $8 Country) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE in_region VALUES($0 Supplier, $6 Region) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE at_address VALUES($0 Supplier, $4 Address) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE has_phone VALUES($0 Supplier, $9 Phone) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE from_company VALUES($0 Supplier, $1 Company) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
    }
END
''')

# %%
results = conn.gsql('''
USE GRAPH Northwind
BEGIN
CREATE LOADING JOB load_job_territories FOR GRAPH Northwind {
      DEFINE FILENAME MyDataSource;
      LOAD MyDataSource TO VERTEX Territory VALUES($0, $1) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
      LOAD MyDataSource TO EDGE in_region VALUES($0 Territory, $2 Region) USING SEPARATOR="|", HEADER="true", EOL="\n", QUOTE="double";
    }
END
''')

# %% [markdown]
# ## Running Loading Jobs

# %% [markdown]
# ### Each Loading Job

# %%
categories_file = "../data/categories.csv"
res = conn.uploadFile(categories_file, fileTag='MyDataSource', jobName='load_job_categories', sep="|")
print(json.dumps(res, indent=2))

# %%
customers_file = "../data/customers.csv"
res = conn.uploadFile(customers_file, fileTag='MyDataSource', jobName='load_job_customers', sep="|")
print(json.dumps(res, indent=2))

# %%
employee_territories_file = "../data/employee_territories.csv"
res = conn.uploadFile(employee_territories_file, fileTag='MyDataSource', jobName='load_job_employee_territories', sep="|")
print(json.dumps(res, indent=2))

# %%
order_details_file = "../data/order_details.csv"
res = conn.uploadFile(order_details_file, fileTag='MyDataSource', jobName='load_job_order_details', sep="|")
print(json.dumps(res, indent=2))

# %%
employees_file = "../data/employees.csv"
res = conn.uploadFile(employees_file, fileTag='MyDataSource', jobName='load_job_employees', sep="|")
print(json.dumps(res, indent=2))

# %%
orders_file = "../data/orders.csv"
res = conn.uploadFile(orders_file, fileTag='MyDataSource', jobName='load_job_orders', sep="|")
print(json.dumps(res, indent=2))

# %%
products_file = "../data/products.csv"
res = conn.uploadFile(products_file, fileTag='MyDataSource', jobName='load_job_products', sep="|")
print(json.dumps(res, indent=2))

# %%
regions_file = "../data/regions.csv"
res = conn.uploadFile(regions_file, fileTag='MyDataSource', jobName='load_job_regions', sep="|")
print(json.dumps(res, indent=2))

# %%
shippers_file = "../data/shippers.csv"
res = conn.uploadFile(shippers_file, fileTag='MyDataSource', jobName='load_job_shippers', sep="|")
print(json.dumps(res, indent=2))

# %%
suppliers_file = '../data/suppliers.csv'
res = conn.uploadFile(suppliers_file, fileTag='MyDataSource', jobName='load_job_suppliers', sep="|")
print(json.dumps(res, indent=2))

# %%
territories_file = "../data/territories.csv"
res = conn.uploadFile(territories_file, fileTag='MyDataSource', jobName='load_job_territories', sep="|")
print(json.dumps(res, indent=2))

# %% [markdown]
# # Running Queries

# %% [markdown]
# ## Interpreting Queries

# %% [markdown]
# ### Subtotal of an Order
# `Price * Quantity * (1 - Discount)` for each item in the given order.

# %%
conn.runInterpretedQuery("""
INTERPRET QUERY get_order_subtotals(VERTEX<CustomerOrder> inOrder) FOR GRAPH Northwind { 
  
  SumAccum<FLOAT> @subtotal;
  
  thisOrder = {inOrder};
  
  results = SELECT o FROM thisOrder:o - (contains_product:e) - Product
    ACCUM
      o.@subtotal += e.unitPrice * e.quantity * (1.0 - e.discount);
  
  PRINT results [results.@subtotal] AS results;
}
""", params={ "inOrder": "11042" }
)
# Out:
# [{'results': [{'v_id': '11042',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.@subtotal': 405.75}}]}]

# %% [markdown]
# ### Sales by Year
# Get all sales subtotals within a given year.

# %%
conn.runInterpretedQuery("""
INTERPRET QUERY get_sales_by_year(int in_year) FOR GRAPH Northwind { 

  SumAccum<FLOAT> @subtotal;
  
  cust_orders = {CustomerOrder.*};
  
  results = SELECT o FROM cust_orders:o - (contains_product:e) - Product
    WHERE
      year(o.shippedDate) == in_year
    ACCUM
      o.@subtotal += e.unitPrice * e.quantity * (1.0 - e.discount)
    ORDER BY
      o.shippedDate;
  
  PRINT results [results.shippedDate, results.@subtotal, year(results.shippedDate)];
}
""", params={ "in_year": "1997" }
)
# Out:
# [{'results': [{'v_id': '10392',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-01-01 00:00:00',
#      'results.@subtotal': 1440,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10397',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-01-02 00:00:00',
#      'results.@subtotal': 716.72003,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10393',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-01-03 00:00:00',
#      'results.@subtotal': 2556.94995,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10395',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-01-03 00:00:00',
#      'results.@subtotal': 2122.91992,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10394',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-01-03 00:00:00',
#      'results.@subtotal': 442,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10396',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-01-06 00:00:00',
#      'results.@subtotal': 1903.80005,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10399',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-01-08 00:00:00',
#      'results.@subtotal': 1765.59998,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10404',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-01-08 00:00:00',
#      'results.@subtotal': 1591.25,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10398',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-01-09 00:00:00',
#      'results.@subtotal': 2505.6001,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10403',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-01-09 00:00:00',
#      'results.@subtotal': 855.01501,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10402',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-01-10 00:00:00',
#      'results.@subtotal': 2713.5,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10401',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-01-10 00:00:00',
#      'results.@subtotal': 3868.6001,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10406',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-01-13 00:00:00',
#      'results.@subtotal': 1830.78003,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10409',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-01-14 00:00:00',
#      'results.@subtotal': 319.20001,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10408',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-01-14 00:00:00',
#      'results.@subtotal': 1622.40002,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10412',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-01-15 00:00:00',
#      'results.@subtotal': 334.79999,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10410',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-01-15 00:00:00',
#      'results.@subtotal': 802,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10380',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-01-16 00:00:00',
#      'results.@subtotal': 1313.81995,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10400',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-01-16 00:00:00',
#      'results.@subtotal': 3063,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10413',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-01-16 00:00:00',
#      'results.@subtotal': 2123.19995,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10414',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-01-17 00:00:00',
#      'results.@subtotal': 224.83002,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10411',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-01-21 00:00:00',
#      'results.@subtotal': 966.79999,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10405',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-01-22 00:00:00',
#      'results.@subtotal': 400,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10418',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-01-24 00:00:00',
#      'results.@subtotal': 1814.80005,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10415',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-01-24 00:00:00',
#      'results.@subtotal': 102.4,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10421',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-01-27 00:00:00',
#      'results.@subtotal': 1194.27002,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10424',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-01-27 00:00:00',
#      'results.@subtotal': 9194.56055,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10416',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-01-27 00:00:00',
#      'results.@subtotal': 720,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10420',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-01-27 00:00:00',
#      'results.@subtotal': 1707.84009,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10417',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-01-28 00:00:00',
#      'results.@subtotal': 11188.40039,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10419',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-01-30 00:00:00',
#      'results.@subtotal': 2097.6001,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10407',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-01-30 00:00:00',
#      'results.@subtotal': 1194,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10422',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-01-31 00:00:00',
#      'results.@subtotal': 49.8,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10430',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-02-03 00:00:00',
#      'results.@subtotal': 4899.2002,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10428',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-02-04 00:00:00',
#      'results.@subtotal': 192,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10426',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-02-06 00:00:00',
#      'results.@subtotal': 338.20001,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10431',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-02-07 00:00:00',
#      'results.@subtotal': 1892.25,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10429',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-02-07 00:00:00',
#      'results.@subtotal': 1441.375,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10435',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-02-07 00:00:00',
#      'results.@subtotal': 631.59998,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10432',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-02-07 00:00:00',
#      'results.@subtotal': 485,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10439',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-02-10 00:00:00',
#      'results.@subtotal': 1078,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10436',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-02-11 00:00:00',
#      'results.@subtotal': 1994.52002,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10437',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-02-12 00:00:00',
#      'results.@subtotal': 393,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10434',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-02-13 00:00:00',
#      'results.@subtotal': 321.11996,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10438',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-02-14 00:00:00',
#      'results.@subtotal': 454,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10443',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-02-14 00:00:00',
#      'results.@subtotal': 517.44,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10425',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-02-14 00:00:00',
#      'results.@subtotal': 360,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10442',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-02-18 00:00:00',
#      'results.@subtotal': 1792,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10446',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-02-19 00:00:00',
#      'results.@subtotal': 246.24001,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10445',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-02-20 00:00:00',
#      'results.@subtotal': 174.89999,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10444',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-02-21 00:00:00',
#      'results.@subtotal': 1031.69995,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10448',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-02-24 00:00:00',
#      'results.@subtotal': 443.39999,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10423',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-02-24 00:00:00',
#      'results.@subtotal': 1020,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10454',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-02-25 00:00:00',
#      'results.@subtotal': 331.20001,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10453',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-02-26 00:00:00',
#      'results.@subtotal': 407.70001,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10452',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-02-26 00:00:00',
#      'results.@subtotal': 2018.5,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10449',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-02-27 00:00:00',
#      'results.@subtotal': 1838.19995,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10456',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-02-28 00:00:00',
#      'results.@subtotal': 557.59998,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10440',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-02-28 00:00:00',
#      'results.@subtotal': 4924.13477,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10459',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-02-28 00:00:00',
#      'results.@subtotal': 1659.20007,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10455',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-03-03 00:00:00',
#      'results.@subtotal': 2684,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10457',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-03-03 00:00:00',
#      'results.@subtotal': 1584,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10460',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-03-03 00:00:00',
#      'results.@subtotal': 176.10001,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10427',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-03-03 00:00:00',
#      'results.@subtotal': 651,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10458',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-03-04 00:00:00',
#      'results.@subtotal': 3891,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10433',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-03-04 00:00:00',
#      'results.@subtotal': 851.20001,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10461',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-03-05 00:00:00',
#      'results.@subtotal': 1538.69995,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10463',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-03-06 00:00:00',
#      'results.@subtotal': 713.29999,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10447',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-03-07 00:00:00',
#      'results.@subtotal': 914.40002,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10467',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-03-11 00:00:00',
#      'results.@subtotal': 235.19998,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10450',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-03-11 00:00:00',
#      'results.@subtotal': 425.12,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10451',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-03-12 00:00:00',
#      'results.@subtotal': 3849.65991,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10468',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-03-12 00:00:00',
#      'results.@subtotal': 717.59998,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10466',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-03-13 00:00:00',
#      'results.@subtotal': 216,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10465',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-03-14 00:00:00',
#      'results.@subtotal': 2518,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10441',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-03-14 00:00:00',
#      'results.@subtotal': 1754.99988,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10470',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-03-14 00:00:00',
#      'results.@subtotal': 1820.80005,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10469',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-03-14 00:00:00',
#      'results.@subtotal': 956.67499,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10464',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-03-14 00:00:00',
#      'results.@subtotal': 1609.28003,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10471',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-03-18 00:00:00',
#      'results.@subtotal': 1328,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10462',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-03-18 00:00:00',
#      'results.@subtotal': 156,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10472',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-03-19 00:00:00',
#      'results.@subtotal': 1036.80005,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10479',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-03-21 00:00:00',
#      'results.@subtotal': 10495.59961,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10474',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-03-21 00:00:00',
#      'results.@subtotal': 1249.09998,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10473',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-03-21 00:00:00',
#      'results.@subtotal': 230.40001,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10480',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-03-24 00:00:00',
#      'results.@subtotal': 756,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10476',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-03-24 00:00:00',
#      'results.@subtotal': 180.48001,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10477',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-03-25 00:00:00',
#      'results.@subtotal': 558,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10481',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-03-25 00:00:00',
#      'results.@subtotal': 1472,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10478',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-03-26 00:00:00',
#      'results.@subtotal': 471.20001,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10487',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-03-28 00:00:00',
#      'results.@subtotal': 889.70001,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10485',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-03-31 00:00:00',
#      'results.@subtotal': 1584,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10484',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-04-01 00:00:00',
#      'results.@subtotal': 386.20001,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10488',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-04-02 00:00:00',
#      'results.@subtotal': 1512,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10486',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-04-02 00:00:00',
#      'results.@subtotal': 1272,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10490',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-04-03 00:00:00',
#      'results.@subtotal': 3163.19995,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10475',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-04-04 00:00:00',
#      'results.@subtotal': 1505.17993,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10497',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-04-07 00:00:00',
#      'results.@subtotal': 1380.59998,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10496',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-04-07 00:00:00',
#      'results.@subtotal': 190,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10491',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-04-08 00:00:00',
#      'results.@subtotal': 259.505,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10489',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-04-09 00:00:00',
#      'results.@subtotal': 439.19998,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10494',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-04-09 00:00:00',
#      'results.@subtotal': 912,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10482',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-04-10 00:00:00',
#      'results.@subtotal': 147,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10493',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-04-10 00:00:00',
#      'results.@subtotal': 608.40002,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10498',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-04-11 00:00:00',
#      'results.@subtotal': 575,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10495',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-04-11 00:00:00',
#      'results.@subtotal': 278,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10492',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-04-11 00:00:00',
#      'results.@subtotal': 851.20001,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10499',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-04-16 00:00:00',
#      'results.@subtotal': 1412,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10501',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-04-16 00:00:00',
#      'results.@subtotal': 149,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10503',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-04-16 00:00:00',
#      'results.@subtotal': 2048.5,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10500',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-04-17 00:00:00',
#      'results.@subtotal': 523.26001,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10504',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-04-18 00:00:00',
#      'results.@subtotal': 1388.5,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10505',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-04-21 00:00:00',
#      'results.@subtotal': 147.89999,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10511',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-04-21 00:00:00',
#      'results.@subtotal': 2550,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10507',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-04-22 00:00:00',
#      'results.@subtotal': 749.0625,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10512',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-04-24 00:00:00',
#      'results.@subtotal': 525.29999,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10483',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-04-25 00:00:00',
#      'results.@subtotal': 668.79999,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10513',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-04-28 00:00:00',
#      'results.@subtotal': 1942,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10510',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-04-28 00:00:00',
#      'results.@subtotal': 4707.54004,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10502',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-04-29 00:00:00',
#      'results.@subtotal': 816.29999,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10509',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-04-29 00:00:00',
#      'results.@subtotal': 136.79999,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10517',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-04-29 00:00:00',
#      'results.@subtotal': 352,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10519',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-05-01 00:00:00',
#      'results.@subtotal': 2314.19995,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10516',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-05-01 00:00:00',
#      'results.@subtotal': 2381.05005,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10520',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-05-01 00:00:00',
#      'results.@subtotal': 200,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10521',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-05-02 00:00:00',
#      'results.@subtotal': 225.5,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10506',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-05-02 00:00:00',
#      'results.@subtotal': 415.79999,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10518',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-05-05 00:00:00',
#      'results.@subtotal': 4150.0498,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10522',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-05-06 00:00:00',
#      'results.@subtotal': 2318.23999,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10527',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-05-07 00:00:00',
#      'results.@subtotal': 1503,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10524',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-05-07 00:00:00',
#      'results.@subtotal': 3192.6499,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10529',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-05-09 00:00:00',
#      'results.@subtotal': 946,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10528',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-05-09 00:00:00',
#      'results.@subtotal': 392.19998,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10530',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-05-12 00:00:00',
#      'results.@subtotal': 4180,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10532',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-05-12 00:00:00',
#      'results.@subtotal': 796.34998,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10508',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-05-13 00:00:00',
#      'results.@subtotal': 240,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10534',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-05-14 00:00:00',
#      'results.@subtotal': 465.70001,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10526',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-05-15 00:00:00',
#      'results.@subtotal': 1151.40002,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10514',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-05-16 00:00:00',
#      'results.@subtotal': 8623.4502,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10538',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-05-16 00:00:00',
#      'results.@subtotal': 139.8,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10537',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-05-19 00:00:00',
#      'results.@subtotal': 1823.80005,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10531',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-05-19 00:00:00',
#      'results.@subtotal': 110,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10535',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-05-21 00:00:00',
#      'results.@subtotal': 1940.84998,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10533',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-05-22 00:00:00',
#      'results.@subtotal': 2222.19995,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10515',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-05-23 00:00:00',
#      'results.@subtotal': 9921.2998,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10539',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-05-23 00:00:00',
#      'results.@subtotal': 355.5,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10525',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-05-23 00:00:00',
#      'results.@subtotal': 818.40002,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10543',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-05-23 00:00:00',
#      'results.@subtotal': 1504.5,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10542',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-05-26 00:00:00',
#      'results.@subtotal': 469.10999,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10546',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-05-27 00:00:00',
#      'results.@subtotal': 2812,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10541',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-05-29 00:00:00',
#      'results.@subtotal': 1946.52002,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10544',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-05-30 00:00:00',
#      'results.@subtotal': 417.19998,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10549',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-05-30 00:00:00',
#      'results.@subtotal': 3554.2749,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10523',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-05-30 00:00:00',
#      'results.@subtotal': 2444.31006,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10548',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-06-02 00:00:00',
#      'results.@subtotal': 240.09999,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10547',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-06-02 00:00:00',
#      'results.@subtotal': 1792.80005,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10553',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-06-03 00:00:00',
#      'results.@subtotal': 1546.30005,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10555',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-06-04 00:00:00',
#      'results.@subtotal': 2944.40015,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10554',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-06-05 00:00:00',
#      'results.@subtotal': 1728.5249,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10552',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-06-05 00:00:00',
#      'results.@subtotal': 880.5,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10536',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-06-06 00:00:00',
#      'results.@subtotal': 1645,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10551',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-06-06 00:00:00',
#      'results.@subtotal': 1677.30005,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10550',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-06-06 00:00:00',
#      'results.@subtotal': 683.29999,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10557',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-06-06 00:00:00',
#      'results.@subtotal': 1152.5,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10561',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-06-09 00:00:00',
#      'results.@subtotal': 2844.5,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10560',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-06-09 00:00:00',
#      'results.@subtotal': 1072.42505,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10558',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-06-10 00:00:00',
#      'results.@subtotal': 2142.8999,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10562',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-06-12 00:00:00',
#      'results.@subtotal': 488.70001,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10540',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-06-13 00:00:00',
#      'results.@subtotal': 10191.7002,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10556',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-06-13 00:00:00',
#      'results.@subtotal': 835.19995,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10559',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-06-13 00:00:00',
#      'results.@subtotal': 520.40997,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10564',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-06-16 00:00:00',
#      'results.@subtotal': 1234.05005,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10567',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-06-17 00:00:00',
#      'results.@subtotal': 2519,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10566',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-06-18 00:00:00',
#      'results.@subtotal': 1761,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10565',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-06-18 00:00:00',
#      'results.@subtotal': 639.90002,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10570',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-06-19 00:00:00',
#      'results.@subtotal': 2465.25,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10573',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-06-20 00:00:00',
#      'results.@subtotal': 2082,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10563',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-06-24 00:00:00',
#      'results.@subtotal': 965,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10572',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-06-25 00:00:00',
#      'results.@subtotal': 1501.08496,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10545',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-06-26 00:00:00',
#      'results.@subtotal': 210,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10575',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-06-30 00:00:00',
#      'results.@subtotal': 2147.3999,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10577',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-06-30 00:00:00',
#      'results.@subtotal': 569,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10574',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-06-30 00:00:00',
#      'results.@subtotal': 764.29999,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10576',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-06-30 00:00:00',
#      'results.@subtotal': 838.45001,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10580',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-07-01 00:00:00',
#      'results.@subtotal': 1013.745,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10581',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-07-02 00:00:00',
#      'results.@subtotal': 310,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10583',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-07-04 00:00:00',
#      'results.@subtotal': 2237.5,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10584',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-07-04 00:00:00',
#      'results.@subtotal': 593.75,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10571',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-07-04 00:00:00',
#      'results.@subtotal': 550.58752,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10579',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-07-04 00:00:00',
#      'results.@subtotal': 317.75,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10586',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-07-09 00:00:00',
#      'results.@subtotal': 23.8,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10587',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-07-09 00:00:00',
#      'results.@subtotal': 807.38,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10568',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-07-09 00:00:00',
#      'results.@subtotal': 155,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10588',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-07-10 00:00:00',
#      'results.@subtotal': 3120,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10585',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-07-10 00:00:00',
#      'results.@subtotal': 142.5,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10569',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-07-11 00:00:00',
#      'results.@subtotal': 890,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10589',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-07-14 00:00:00',
#      'results.@subtotal': 72,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10595',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-07-14 00:00:00',
#      'results.@subtotal': 4725,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10590',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-07-14 00:00:00',
#      'results.@subtotal': 1101,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10582',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-07-14 00:00:00',
#      'results.@subtotal': 330,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10594',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-07-16 00:00:00',
#      'results.@subtotal': 565.5,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10591',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-07-16 00:00:00',
#      'results.@subtotal': 812.5,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10592',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-07-16 00:00:00',
#      'results.@subtotal': 516.46753,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10597',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-07-18 00:00:00',
#      'results.@subtotal': 718.07996,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10598',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-07-18 00:00:00',
#      'results.@subtotal': 2388.5,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10599',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-07-21 00:00:00',
#      'results.@subtotal': 493,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10600',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-07-21 00:00:00',
#      'results.@subtotal': 479.79999,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10601',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-07-22 00:00:00',
#      'results.@subtotal': 2285,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10602',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-07-22 00:00:00',
#      'results.@subtotal': 48.75,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10578',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-07-25 00:00:00',
#      'results.@subtotal': 477,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10607',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-07-25 00:00:00',
#      'results.@subtotal': 6475.3999,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10604',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-07-29 00:00:00',
#      'results.@subtotal': 230.85001,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10605',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-07-29 00:00:00',
#      'results.@subtotal': 4109.7002,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10609',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-07-30 00:00:00',
#      'results.@subtotal': 424,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10606',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-07-31 00:00:00',
#      'results.@subtotal': 1130.40002,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10608',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-08-01 00:00:00',
#      'results.@subtotal': 1064,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10612',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-08-01 00:00:00',
#      'results.@subtotal': 6375,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10613',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-08-01 00:00:00',
#      'results.@subtotal': 353.20001,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10611',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-08-01 00:00:00',
#      'results.@subtotal': 808,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10614',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-08-01 00:00:00',
#      'results.@subtotal': 464,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10617',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-08-04 00:00:00',
#      'results.@subtotal': 1402.5,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10616',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-08-05 00:00:00',
#      'results.@subtotal': 4807,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10615',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-08-06 00:00:00',
#      'results.@subtotal': 120,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10610',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-08-06 00:00:00',
#      'results.@subtotal': 299.25,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10619',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-08-07 00:00:00',
#      'results.@subtotal': 1260,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10603',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-08-08 00:00:00',
#      'results.@subtotal': 1483,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10618',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-08-08 00:00:00',
#      'results.@subtotal': 2697.5,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10621',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-08-11 00:00:00',
#      'results.@subtotal': 758.5,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10622',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-08-11 00:00:00',
#      'results.@subtotal': 560,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10623',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-08-12 00:00:00',
#      'results.@subtotal': 1336.94995,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10596',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-08-12 00:00:00',
#      'results.@subtotal': 1180.88013,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10593',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-08-13 00:00:00',
#      'results.@subtotal': 1994.40002,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10620',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-08-14 00:00:00',
#      'results.@subtotal': 57.5,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10625',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-08-14 00:00:00',
#      'results.@subtotal': 479.75,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10631',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-08-15 00:00:00',
#      'results.@subtotal': 55.8,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10633',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-08-18 00:00:00',
#      'results.@subtotal': 5510.59229,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10630',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-08-19 00:00:00',
#      'results.@subtotal': 903.59998,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10632',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-08-19 00:00:00',
#      'results.@subtotal': 589,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10624',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-08-19 00:00:00',
#      'results.@subtotal': 1393.23999,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10626',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-08-20 00:00:00',
#      'results.@subtotal': 1503.59998,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10629',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-08-20 00:00:00',
#      'results.@subtotal': 2775.05005,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10628',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-08-20 00:00:00',
#      'results.@subtotal': 450,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10635',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-08-21 00:00:00',
#      'results.@subtotal': 1326.22498,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10627',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-08-21 00:00:00',
#      'results.@subtotal': 1185.75,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10634',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-08-21 00:00:00',
#      'results.@subtotal': 4985.5,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10636',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-08-26 00:00:00',
#      'results.@subtotal': 629.5,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10637',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-08-26 00:00:00',
#      'results.@subtotal': 2761.9375,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10641',
#     'v_type': 'CustomerOrder',
# ...
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-10-24 00:00:00',
#      'results.@subtotal': 2827.8999,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10716',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-10-27 00:00:00',
#      'results.@subtotal': 706,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10714',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-10-27 00:00:00',
#      'results.@subtotal': 2205.75,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10717',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-10-29 00:00:00',
#      'results.@subtotal': 1270.75,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10711',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-10-29 00:00:00',
#      'results.@subtotal': 4451.7002,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10715',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-10-29 00:00:00',
#      'results.@subtotal': 1296,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10718',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-10-29 00:00:00',
#      'results.@subtotal': 3463,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10687',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-10-30 00:00:00',
#      'results.@subtotal': 4960.8999,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10721',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-10-31 00:00:00',
#      'results.@subtotal': 923.87506,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10712',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-10-31 00:00:00',
#      'results.@subtotal': 1233.47998,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10722',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-04 00:00:00',
#      'results.@subtotal': 1570,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10725',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-05 00:00:00',
#      'results.@subtotal': 287.79999,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10719',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-05 00:00:00',
#      'results.@subtotal': 844.2525,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10708',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-05 00:00:00',
#      'results.@subtotal': 180.39999,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10720',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-05 00:00:00',
#      'results.@subtotal': 550,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10724',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-05 00:00:00',
#      'results.@subtotal': 638.5,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10732',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-07 00:00:00',
#      'results.@subtotal': 360,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10704',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-07 00:00:00',
#      'results.@subtotal': 595.5,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10733',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-10 00:00:00',
#      'results.@subtotal': 1459,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10728',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-11 00:00:00',
#      'results.@subtotal': 1296.75,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10734',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-12 00:00:00',
#      'results.@subtotal': 1498.34998,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10731',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-14 00:00:00',
#      'results.@subtotal': 1890.5,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10730',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-14 00:00:00',
#      'results.@subtotal': 484.26251,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10729',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-14 00:00:00',
#      'results.@subtotal': 1850,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10739',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-17 00:00:00',
#      'results.@subtotal': 240,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10737',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-18 00:00:00',
#      'results.@subtotal': 139.79999,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10705',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-18 00:00:00',
#      'results.@subtotal': 378,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10741',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-18 00:00:00',
#      'results.@subtotal': 228,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10738',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-18 00:00:00',
#      'results.@subtotal': 52.35,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10742',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-18 00:00:00',
#      'results.@subtotal': 3118,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10709',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-20 00:00:00',
#      'results.@subtotal': 3424,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10746',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-21 00:00:00',
#      'results.@subtotal': 2311.69995,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10743',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-21 00:00:00',
#      'results.@subtotal': 319.20001,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10735',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-21 00:00:00',
#      'results.@subtotal': 536.40002,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10736',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-21 00:00:00',
#      'results.@subtotal': 997,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10750',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-24 00:00:00',
#      'results.@subtotal': 1590.5625,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10744',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-24 00:00:00',
#      'results.@subtotal': 736,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10740',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-25 00:00:00',
#      'results.@subtotal': 1416,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10723',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-25 00:00:00',
#      'results.@subtotal': 468.44998,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10747',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-26 00:00:00',
#      'results.@subtotal': 1912.84998,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10754',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-27 00:00:00',
#      'results.@subtotal': 55.2,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10745',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-27 00:00:00',
#      'results.@subtotal': 4529.7998,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10753',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-27 00:00:00',
#      'results.@subtotal': 88,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10755',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-28 00:00:00',
#      'results.@subtotal': 1948.5,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10752',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-28 00:00:00',
#      'results.@subtotal': 252,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10748',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-11-28 00:00:00',
#      'results.@subtotal': 2196,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10756',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-02 00:00:00',
#      'results.@subtotal': 1990,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10751',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-03 00:00:00',
#      'results.@subtotal': 1631.48389,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10758',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-04 00:00:00',
#      'results.@subtotal': 1644.59998,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10726',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-05 00:00:00',
#      'results.@subtotal': 655,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10727',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-05 00:00:00',
#      'results.@subtotal': 1624.5,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10761',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-08 00:00:00',
#      'results.@subtotal': 507,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10763',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-08 00:00:00',
#      'results.@subtotal': 616,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10764',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-08 00:00:00',
#      'results.@subtotal': 2286,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10762',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-09 00:00:00',
#      'results.@subtotal': 4337,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10765',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-09 00:00:00',
#      'results.@subtotal': 1515.59998,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10766',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-09 00:00:00',
#      'results.@subtotal': 2310,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10760',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-10 00:00:00',
#      'results.@subtotal': 2917,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10759',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-12 00:00:00',
#      'results.@subtotal': 320,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10769',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-12 00:00:00',
#      'results.@subtotal': 1684.27502,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10774',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-12 00:00:00',
#      'results.@subtotal': 868.75,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10768',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-15 00:00:00',
#      'results.@subtotal': 1477,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10767',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-15 00:00:00',
#      'results.@subtotal': 28,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10757',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-15 00:00:00',
#      'results.@subtotal': 3082,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10773',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-16 00:00:00',
#      'results.@subtotal': 2030.40002,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10770',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-17 00:00:00',
#      'results.@subtotal': 236.25,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10776',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-18 00:00:00',
#      'results.@subtotal': 6635.2749,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10781',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-19 00:00:00',
#      'results.@subtotal': 975.88,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10749',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-19 00:00:00',
#      'results.@subtotal': 1080,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10772',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-19 00:00:00',
#      'results.@subtotal': 3603.21997,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10783',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-19 00:00:00',
#      'results.@subtotal': 1442.5,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10782',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-22 00:00:00',
#      'results.@subtotal': 12.5,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10784',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-22 00:00:00',
#      'results.@subtotal': 1488,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10786',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-23 00:00:00',
#      'results.@subtotal': 1531.07996,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10778',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-24 00:00:00',
#      'results.@subtotal': 96.5,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10785',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-24 00:00:00',
#      'results.@subtotal': 387.5,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10780',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-25 00:00:00',
#      'results.@subtotal': 720,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10790',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-26 00:00:00',
#      'results.@subtotal': 722.5,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10775',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-26 00:00:00',
#      'results.@subtotal': 228,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10787',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-26 00:00:00',
#      'results.@subtotal': 2622.76001,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10801',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-31 00:00:00',
#      'results.@subtotal': 3026.8501,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10789',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-31 00:00:00',
#      'results.@subtotal': 3687,
#      'year(results.shippedDate)': 1997}},
#    {'v_id': '10792',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.shippedDate': '1997-12-31 00:00:00',
#      'results.@subtotal': 399.85001,
#      'year(results.shippedDate)': 1997}}]}]

# %% [markdown]
# ### Employee Sales by Country
# Get all employees sales subtotal in a given Country.

# %%
conn.runInterpretedQuery("""
INTERPRET QUERY get_employee_sales_by_country(VERTEX<Country> in_cont) FOR GRAPH Northwind SYNTAX v2{ 
  
  country = {in_cont};
  
  SumAccum<FLOAT> @subtotal;
  
  orders = SELECT o FROM country:c - (to_country) - CustomerOrder:o;
  
  subs = SELECT o FROM orders:o - (contains_product:e) - Product
    ACCUM
      o.@subtotal += e.unitPrice * e.quantity * (1.0 - e.discount);
    
  results = SELECT e FROM country:c - (to_country) - CustomerOrder:o - (facilitated_order) - Employee:e
    ACCUM
      e.@subtotal += o.@subtotal;
  
  PRINT country;
  PRINT results [results.firstName, results.lastName, results.@subtotal];
  
}
""", params={ "in_cont": "USA" }
)
# Out:
# [{'country': [{'v_id': 'USA',
#     'v_type': 'Country',
#     'attributes': {'id': '', '@subtotal': 0}}]},
#  {'results': [{'v_id': '7',
#     'v_type': 'Employee',
#     'attributes': {'results.firstName': 'Robert',
#      'results.lastName': 'King',
#      'results.@subtotal': 23850.44922}},
#    {'v_id': '8',
#     'v_type': 'Employee',
#     'attributes': {'results.firstName': 'Laura',
#      'results.lastName': 'Callahan',
#      'results.@subtotal': 25755.48438}},
#    {'v_id': '4',
#     'v_type': 'Employee',
#     'attributes': {'results.firstName': 'Margaret',
#      'results.lastName': 'Peacock',
#      'results.@subtotal': 46384.83594}},
#    {'v_id': '2',
#     'v_type': 'Employee',
#     'attributes': {'results.firstName': 'Andrew',
#      'results.lastName': 'Fuller',
#      'results.@subtotal': 22054.34961}},
#    {'v_id': '5',
#     'v_type': 'Employee',
#     'attributes': {'results.firstName': 'Steven',
#      'results.lastName': 'Buchanan',
#      'results.@subtotal': 15172.05078}},
#    {'v_id': '3',
#     'v_type': 'Employee',
#     'attributes': {'results.firstName': 'Janet',
#      'results.lastName': 'Leverling',
#      'results.@subtotal': 33564.45313}},
#    {'v_id': '9',
#     'v_type': 'Employee',
#     'attributes': {'results.firstName': 'Anne',
#      'results.lastName': 'Dodsworth',
#      'results.@subtotal': 17224.71484}},
#    {'v_id': '1',
#     'v_type': 'Employee',
#     'attributes': {'results.firstName': 'Nancy',
#      'results.lastName': 'Davolio',
#      'results.@subtotal': 43761.32031}},
#    {'v_id': '6',
#     'v_type': 'Employee',
#     'attributes': {'results.firstName': '',
#      'results.lastName': '',
#      'results.@subtotal': 17816.95508}}]}]

# %% [markdown]
# ### Alphabetical Products
# List all products in alphabetical order.

# %%
conn.runInterpretedQuery("""
INTERPRET QUERY alphabetical_products() FOR GRAPH Northwind { 
  products = {Product.*};
  
  results = SELECT p FROM products:p
    ORDER BY
      p.productName ASC;
  
  PRINT results;
}
""")
# Out:
# [{'results': [{'v_id': 'ProductID',
#     'v_type': 'Product',
#     'attributes': {'id': 0,
#      'productName': '',
#      'qtyPerUnit': '',
#      'unitPrice': 0,
#      'inStock': 0,
#      'onOrder': 0,
#      'reorderLevel': 0,
#      'discontinued': False}},
#    {'v_id': '17',
#     'v_type': 'Product',
#     'attributes': {'id': 17,
#      'productName': 'Alice Mutton',
#      'qtyPerUnit': '20 - 1 kg tins',
#      'unitPrice': 39,
#      'inStock': 0,
#      'onOrder': 0,
#      'reorderLevel': 0,
#      'discontinued': True}},
#    {'v_id': '3',
#     'v_type': 'Product',
#     'attributes': {'id': 3,
#      'productName': 'Aniseed Syrup',
#      'qtyPerUnit': '12 - 550 ml bottles',
#      'unitPrice': 10,
#      'inStock': 13,
#      'onOrder': 70,
#      'reorderLevel': 25,
#      'discontinued': False}},
#    {'v_id': '40',
#     'v_type': 'Product',
#     'attributes': {'id': 40,
#      'productName': 'Boston Crab Meat',
#      'qtyPerUnit': '24 - 4 oz tins',
#      'unitPrice': 18.4,
#      'inStock': 123,
#      'onOrder': 0,
#      'reorderLevel': 30,
#      'discontinued': False}},
#    {'v_id': '60',
#     'v_type': 'Product',
#     'attributes': {'id': 60,
#      'productName': 'Camembert Pierrot',
#      'qtyPerUnit': '15 - 300 g rounds',
#      'unitPrice': 34,
#      'inStock': 19,
#      'onOrder': 0,
#      'reorderLevel': 0,
#      'discontinued': False}},
#    {'v_id': '18',
#     'v_type': 'Product',
#     'attributes': {'id': 18,
#      'productName': 'Carnarvon Tigers',
#      'qtyPerUnit': '16 kg pkg.',
#      'unitPrice': 62.5,
#      'inStock': 42,
#      'onOrder': 0,
#      'reorderLevel': 0,
#      'discontinued': False}},
#    {'v_id': '1',
#     'v_type': 'Product',
#     'attributes': {'id': 1,
#      'productName': 'Chai',
#      'qtyPerUnit': '10 boxes x 20 bags',
#      'unitPrice': 18,
#      'inStock': 39,
#      'onOrder': 0,
#      'reorderLevel': 10,
#      'discontinued': False}},
#    {'v_id': '2',
#     'v_type': 'Product',
#     'attributes': {'id': 2,
#      'productName': 'Chang',
#      'qtyPerUnit': '24 - 12 oz bottles',
#      'unitPrice': 19,
#      'inStock': 17,
#      'onOrder': 40,
#      'reorderLevel': 25,
#      'discontinued': False}},
#    {'v_id': '39',
#     'v_type': 'Product',
#     'attributes': {'id': 39,
#      'productName': 'Chartreuse verte',
#      'qtyPerUnit': '750 cc per bottle',
#      'unitPrice': 18,
#      'inStock': 69,
#      'onOrder': 0,
#      'reorderLevel': 5,
#      'discontinued': False}},
#    {'v_id': '4',
#     'v_type': 'Product',
#     'attributes': {'id': 4,
#      'productName': "Chef Anton's Cajun Seasoning",
#      'qtyPerUnit': '48 - 6 oz jars',
#      'unitPrice': 22,
#      'inStock': 53,
#      'onOrder': 0,
#      'reorderLevel': 0,
#      'discontinued': False}},
#    {'v_id': '5',
#     'v_type': 'Product',
#     'attributes': {'id': 5,
#      'productName': "Chef Anton's Gumbo Mix",
#      'qtyPerUnit': '36 boxes',
#      'unitPrice': 21.35,
#      'inStock': 0,
#      'onOrder': 0,
#      'reorderLevel': 0,
#      'discontinued': True}},
#    {'v_id': '48',
#     'v_type': 'Product',
#     'attributes': {'id': 48,
#      'productName': 'Chocolade',
#      'qtyPerUnit': '10 pkgs.',
#      'unitPrice': 12.75,
#      'inStock': 15,
#      'onOrder': 70,
#      'reorderLevel': 25,
#      'discontinued': False}},
#    {'v_id': '38',
#     'v_type': 'Product',
#     'attributes': {'id': 38,
#      'productName': 'Côte de Blaye',
#      'qtyPerUnit': '12 - 75 cl bottles',
#      'unitPrice': 263.5,
#      'inStock': 17,
#      'onOrder': 0,
#      'reorderLevel': 15,
#      'discontinued': False}},
#    {'v_id': '58',
#     'v_type': 'Product',
#     'attributes': {'id': 58,
#      'productName': 'Escargots de Bourgogne',
#      'qtyPerUnit': '24 pieces',
#      'unitPrice': 13.25,
#      'inStock': 62,
#      'onOrder': 0,
#      'reorderLevel': 20,
#      'discontinued': False}},
#    {'v_id': '52',
#     'v_type': 'Product',
#     'attributes': {'id': 52,
#      'productName': 'Filo Mix',
#      'qtyPerUnit': '16 - 2 kg boxes',
#      'unitPrice': 7,
#      'inStock': 38,
#      'onOrder': 0,
#      'reorderLevel': 25,
#      'discontinued': False}},
#    {'v_id': '71',
#     'v_type': 'Product',
#     'attributes': {'id': 71,
#      'productName': 'Flotemysost',
#      'qtyPerUnit': '10 - 500 g pkgs.',
#      'unitPrice': 21.5,
#      'inStock': 26,
#      'onOrder': 0,
#      'reorderLevel': 0,
#      'discontinued': False}},
#    {'v_id': '33',
#     'v_type': 'Product',
#     'attributes': {'id': 33,
#      'productName': 'Geitost',
#      'qtyPerUnit': '500 g',
#      'unitPrice': 2.5,
#      'inStock': 112,
#      'onOrder': 0,
#      'reorderLevel': 20,
#      'discontinued': False}},
#    {'v_id': '15',
#     'v_type': 'Product',
#     'attributes': {'id': 15,
#      'productName': 'Genen Shouyu',
#      'qtyPerUnit': '24 - 250 ml bottles',
#      'unitPrice': 15.5,
#      'inStock': 39,
#      'onOrder': 0,
#      'reorderLevel': 5,
#      'discontinued': False}},
#    {'v_id': '56',
#     'v_type': 'Product',
#     'attributes': {'id': 56,
#      'productName': 'Gnocchi di nonna Alice',
#      'qtyPerUnit': '24 - 250 g pkgs.',
#      'unitPrice': 38,
#      'inStock': 21,
#      'onOrder': 10,
#      'reorderLevel': 30,
#      'discontinued': False}},
#    {'v_id': '31',
#     'v_type': 'Product',
#     'attributes': {'id': 31,
#      'productName': 'Gorgonzola Telino',
#      'qtyPerUnit': '12 - 100 g pkgs',
#      'unitPrice': 12.5,
#      'inStock': 0,
#      'onOrder': 70,
#      'reorderLevel': 20,
#      'discontinued': False}},
#    {'v_id': '6',
#     'v_type': 'Product',
#     'attributes': {'id': 6,
#      'productName': "Grandma's Boysenberry Spread",
#      'qtyPerUnit': '12 - 8 oz jars',
#      'unitPrice': 25,
#      'inStock': 120,
#      'onOrder': 0,
#      'reorderLevel': 25,
#      'discontinued': False}},
#    {'v_id': '37',
#     'v_type': 'Product',
#     'attributes': {'id': 37,
#      'productName': 'Gravad lax',
#      'qtyPerUnit': '12 - 500 g pkgs.',
#      'unitPrice': 26,
#      'inStock': 11,
#      'onOrder': 50,
#      'reorderLevel': 25,
#      'discontinued': False}},
#    {'v_id': '24',
#     'v_type': 'Product',
#     'attributes': {'id': 24,
#      'productName': 'Guaraná Fantástica',
#      'qtyPerUnit': '12 - 355 ml cans',
#      'unitPrice': 4.5,
#      'inStock': 20,
#      'onOrder': 0,
#      'reorderLevel': 0,
#      'discontinued': True}},
#    {'v_id': '69',
#     'v_type': 'Product',
#     'attributes': {'id': 69,
#      'productName': 'Gudbrandsdalsost',
#      'qtyPerUnit': '10 kg pkg.',
#      'unitPrice': 36,
#      'inStock': 26,
#      'onOrder': 0,
#      'reorderLevel': 15,
#      'discontinued': False}},
#    {'v_id': '44',
#     'v_type': 'Product',
#     'attributes': {'id': 44,
#      'productName': 'Gula Malacca',
#      'qtyPerUnit': '20 - 2 kg bags',
#      'unitPrice': 19.45,
#      'inStock': 27,
#      'onOrder': 0,
#      'reorderLevel': 15,
#      'discontinued': False}},
#    {'v_id': '26',
#     'v_type': 'Product',
#     'attributes': {'id': 26,
#      'productName': 'Gumbär Gummibärchen',
#      'qtyPerUnit': '100 - 250 g bags',
#      'unitPrice': 31.23,
#      'inStock': 15,
#      'onOrder': 0,
#      'reorderLevel': 0,
#      'discontinued': False}},
#    {'v_id': '22',
#     'v_type': 'Product',
#     'attributes': {'id': 22,
#      'productName': "Gustaf's Knäckebröd",
#      'qtyPerUnit': '24 - 500 g pkgs.',
#      'unitPrice': 21,
#      'inStock': 104,
#      'onOrder': 0,
#      'reorderLevel': 25,
#      'discontinued': False}},
#    {'v_id': '10',
#     'v_type': 'Product',
#     'attributes': {'id': 10,
#      'productName': 'Ikura',
#      'qtyPerUnit': '12 - 200 ml jars',
#      'unitPrice': 31,
#      'inStock': 31,
#      'onOrder': 0,
#      'reorderLevel': 0,
#      'discontinued': False}},
#    {'v_id': '36',
#     'v_type': 'Product',
#     'attributes': {'id': 36,
#      'productName': 'Inlagd Sill',
#      'qtyPerUnit': '24 - 250 g  jars',
#      'unitPrice': 19,
#      'inStock': 112,
#      'onOrder': 0,
#      'reorderLevel': 20,
#      'discontinued': False}},
#    {'v_id': '43',
#     'v_type': 'Product',
#     'attributes': {'id': 43,
#      'productName': 'Ipoh Coffee',
#      'qtyPerUnit': '16 - 500 g tins',
#      'unitPrice': 46,
#      'inStock': 17,
#      'onOrder': 10,
#      'reorderLevel': 25,
#      'discontinued': False}},
#    {'v_id': '41',
#     'v_type': 'Product',
#     'attributes': {'id': 41,
#      'productName': "Jack's New England Clam Chowder",
#      'qtyPerUnit': '12 - 12 oz cans',
#      'unitPrice': 9.65,
#      'inStock': 85,
#      'onOrder': 0,
#      'reorderLevel': 10,
#      'discontinued': False}},
#    {'v_id': '13',
#     'v_type': 'Product',
#     'attributes': {'id': 13,
#      'productName': 'Konbu',
#      'qtyPerUnit': '2 kg box',
#      'unitPrice': 6,
#      'inStock': 24,
#      'onOrder': 0,
#      'reorderLevel': 5,
#      'discontinued': False}},
#    {'v_id': '76',
#     'v_type': 'Product',
#     'attributes': {'id': 76,
#      'productName': 'Lakkalikööri',
#      'qtyPerUnit': '500 ml',
#      'unitPrice': 18,
#      'inStock': 57,
#      'onOrder': 0,
#      'reorderLevel': 20,
#      'discontinued': False}},
#    {'v_id': '67',
#     'v_type': 'Product',
#     'attributes': {'id': 67,
#      'productName': 'Laughing Lumberjack Lager',
#      'qtyPerUnit': '24 - 12 oz bottles',
#      'unitPrice': 14,
#      'inStock': 52,
#      'onOrder': 0,
#      'reorderLevel': 10,
#      'discontinued': False}},
#    {'v_id': '74',
#     'v_type': 'Product',
#     'attributes': {'id': 74,
#      'productName': 'Longlife Tofu',
#      'qtyPerUnit': '5 kg pkg.',
#      'unitPrice': 10,
#      'inStock': 4,
#      'onOrder': 20,
#      'reorderLevel': 5,
#      'discontinued': False}},
#    {'v_id': '65',
#     'v_type': 'Product',
#     'attributes': {'id': 65,
#      'productName': 'Louisiana Fiery Hot Pepper Sauce',
#      'qtyPerUnit': '32 - 8 oz bottles',
#      'unitPrice': 21.05,
#      'inStock': 76,
#      'onOrder': 0,
#      'reorderLevel': 0,
#      'discontinued': False}},
#    {'v_id': '66',
#     'v_type': 'Product',
#     'attributes': {'id': 66,
#      'productName': 'Louisiana Hot Spiced Okra',
#      'qtyPerUnit': '24 - 8 oz jars',
#      'unitPrice': 17,
#      'inStock': 4,
#      'onOrder': 100,
#      'reorderLevel': 20,
#      'discontinued': False}},
#    {'v_id': '51',
#     'v_type': 'Product',
#     'attributes': {'id': 51,
#      'productName': 'Manjimup Dried Apples',
#      'qtyPerUnit': '50 - 300 g pkgs.',
#      'unitPrice': 53,
#      'inStock': 20,
#      'onOrder': 0,
#      'reorderLevel': 10,
#      'discontinued': False}},
#    {'v_id': '32',
#     'v_type': 'Product',
#     'attributes': {'id': 32,
#      'productName': 'Mascarpone Fabioli',
#      'qtyPerUnit': '24 - 200 g pkgs.',
#      'unitPrice': 32,
#      'inStock': 9,
#      'onOrder': 40,
#      'reorderLevel': 25,
#      'discontinued': False}},
#    {'v_id': '49',
#     'v_type': 'Product',
#     'attributes': {'id': 49,
#      'productName': 'Maxilaku',
#      'qtyPerUnit': '24 - 50 g pkgs.',
#      'unitPrice': 20,
#      'inStock': 10,
#      'onOrder': 60,
#      'reorderLevel': 15,
#      'discontinued': False}},
#    {'v_id': '9',
#     'v_type': 'Product',
#     'attributes': {'id': 9,
#      'productName': 'Mishi Kobe Niku',
#      'qtyPerUnit': '18 - 500 g pkgs.',
#      'unitPrice': 97,
#      'inStock': 29,
#      'onOrder': 0,
#      'reorderLevel': 0,
#      'discontinued': True}},
#    {'v_id': '72',
#     'v_type': 'Product',
#     'attributes': {'id': 72,
#      'productName': 'Mozzarella di Giovanni',
#      'qtyPerUnit': '24 - 200 g pkgs.',
#      'unitPrice': 34.8,
#      'inStock': 14,
#      'onOrder': 0,
#      'reorderLevel': 0,
#      'discontinued': False}},
#    {'v_id': '30',
#     'v_type': 'Product',
#     'attributes': {'id': 30,
#      'productName': 'Nord-Ost Matjeshering',
#      'qtyPerUnit': '10 - 200 g glasses',
#      'unitPrice': 25.89,
#      'inStock': 10,
#      'onOrder': 0,
#      'reorderLevel': 15,
#      'discontinued': False}},
#    {'v_id': '8',
#     'v_type': 'Product',
#     'attributes': {'id': 8,
#      'productName': 'Northwoods Cranberry Sauce',
#      'qtyPerUnit': '12 - 12 oz jars',
#      'unitPrice': 40,
#      'inStock': 6,
#      'onOrder': 0,
#      'reorderLevel': 0,
#      'discontinued': False}},
#    {'v_id': '25',
#     'v_type': 'Product',
#     'attributes': {'id': 25,
#      'productName': 'NuNuCa Nuß-Nougat-Creme',
#      'qtyPerUnit': '20 - 450 g glasses',
#      'unitPrice': 14,
#      'inStock': 76,
#      'onOrder': 0,
#      'reorderLevel': 30,
#      'discontinued': False}},
#    {'v_id': '77',
#     'v_type': 'Product',
#     'attributes': {'id': 77,
#      'productName': 'Original Frankfurter grüne Soße',
#      'qtyPerUnit': '12 boxes',
#      'unitPrice': 13,
#      'inStock': 32,
#      'onOrder': 0,
#      'reorderLevel': 15,
#      'discontinued': False}},
#    {'v_id': '70',
#     'v_type': 'Product',
#     'attributes': {'id': 70,
#      'productName': 'Outback Lager',
#      'qtyPerUnit': '24 - 355 ml bottles',
#      'unitPrice': 15,
#      'inStock': 15,
#      'onOrder': 10,
#      'reorderLevel': 30,
#      'discontinued': False}},
#    {'v_id': '16',
#     'v_type': 'Product',
#     'attributes': {'id': 16,
#      'productName': 'Pavlova',
#      'qtyPerUnit': '32 - 500 g boxes',
#      'unitPrice': 17.45,
#      'inStock': 29,
#      'onOrder': 0,
#      'reorderLevel': 10,
#      'discontinued': False}},
#    {'v_id': '53',
#     'v_type': 'Product',
#     'attributes': {'id': 53,
#      'productName': 'Perth Pasties',
#      'qtyPerUnit': '48 pieces',
#      'unitPrice': 32.8,
#      'inStock': 0,
#      'onOrder': 0,
#      'reorderLevel': 0,
#      'discontinued': True}},
#    {'v_id': '55',
#     'v_type': 'Product',
#     'attributes': {'id': 55,
#      'productName': 'Pâté chinois',
#      'qtyPerUnit': '24 boxes x 2 pies',
#      'unitPrice': 24,
#      'inStock': 115,
#      'onOrder': 0,
#      'reorderLevel': 20,
#      'discontinued': False}},
#    {'v_id': '11',
#     'v_type': 'Product',
#     'attributes': {'id': 11,
#      'productName': 'Queso Cabrales',
#      'qtyPerUnit': '1 kg pkg.',
#      'unitPrice': 21,
#      'inStock': 22,
#      'onOrder': 30,
#      'reorderLevel': 30,
#      'discontinued': False}},
#    {'v_id': '12',
#     'v_type': 'Product',
#     'attributes': {'id': 12,
#      'productName': 'Queso Manchego La Pastora',
#      'qtyPerUnit': '10 - 500 g pkgs.',
#      'unitPrice': 38,
#      'inStock': 86,
#      'onOrder': 0,
#      'reorderLevel': 0,
#      'discontinued': False}},
#    {'v_id': '59',
#     'v_type': 'Product',
#     'attributes': {'id': 59,
#      'productName': 'Raclette Courdavault',
#      'qtyPerUnit': '5 kg pkg.',
#      'unitPrice': 55,
#      'inStock': 79,
#      'onOrder': 0,
#      'reorderLevel': 0,
#      'discontinued': False}},
#    {'v_id': '57',
#     'v_type': 'Product',
#     'attributes': {'id': 57,
#      'productName': 'Ravioli Angelo',
#      'qtyPerUnit': '24 - 250 g pkgs.',
#      'unitPrice': 19.5,
#      'inStock': 36,
#      'onOrder': 0,
#      'reorderLevel': 20,
#      'discontinued': False}},
#    {'v_id': '75',
#     'v_type': 'Product',
#     'attributes': {'id': 75,
#      'productName': 'Rhönbräu Klosterbier',
#      'qtyPerUnit': '24 - 0.5 l bottles',
#      'unitPrice': 7.75,
#      'inStock': 125,
#      'onOrder': 0,
#      'reorderLevel': 25,
#      'discontinued': False}},
#    {'v_id': '45',
#     'v_type': 'Product',
#     'attributes': {'id': 45,
#      'productName': 'Rogede sild',
#      'qtyPerUnit': '1k pkg.',
#      'unitPrice': 9.5,
#      'inStock': 5,
#      'onOrder': 70,
#      'reorderLevel': 15,
#      'discontinued': False}},
#    {'v_id': '73',
#     'v_type': 'Product',
#     'attributes': {'id': 73,
#      'productName': 'Röd Kaviar',
#      'qtyPerUnit': '24 - 150 g jars',
#      'unitPrice': 15,
#      'inStock': 101,
#      'onOrder': 0,
#      'reorderLevel': 5,
#      'discontinued': False}},
#    {'v_id': '28',
#     'v_type': 'Product',
#     'attributes': {'id': 28,
#      'productName': 'Rössle Sauerkraut',
#      'qtyPerUnit': '25 - 825 g cans',
#      'unitPrice': 45.6,
#      'inStock': 26,
#      'onOrder': 0,
#      'reorderLevel': 0,
#      'discontinued': True}},
#    {'v_id': '34',
#     'v_type': 'Product',
#     'attributes': {'id': 34,
#      'productName': 'Sasquatch Ale',
#      'qtyPerUnit': '24 - 12 oz bottles',
#      'unitPrice': 14,
#      'inStock': 111,
#      'onOrder': 0,
#      'reorderLevel': 15,
#      'discontinued': False}},
#    {'v_id': '27',
#     'v_type': 'Product',
#     'attributes': {'id': 27,
#      'productName': 'Schoggi Schokolade',
#      'qtyPerUnit': '100 - 100 g pieces',
#      'unitPrice': 43.9,
#      'inStock': 49,
#      'onOrder': 0,
#      'reorderLevel': 30,
#      'discontinued': False}},
#    {'v_id': '68',
#     'v_type': 'Product',
#     'attributes': {'id': 68,
#      'productName': 'Scottish Longbreads',
#      'qtyPerUnit': '10 boxes x 8 pieces',
#      'unitPrice': 12.5,
#      'inStock': 6,
#      'onOrder': 10,
#      'reorderLevel': 15,
#      'discontinued': False}},
#    {'v_id': '42',
#     'v_type': 'Product',
#     'attributes': {'id': 42,
#      'productName': 'Singaporean Hokkien Fried Mee',
#      'qtyPerUnit': '32 - 1 kg pkgs.',
#      'unitPrice': 14,
#      'inStock': 26,
#      'onOrder': 0,
#      'reorderLevel': 0,
#      'discontinued': True}},
#    {'v_id': '20',
#     'v_type': 'Product',
#     'attributes': {'id': 20,
#      'productName': "Sir Rodney's Marmalade",
#      'qtyPerUnit': '30 gift boxes',
#      'unitPrice': 81,
#      'inStock': 40,
#      'onOrder': 0,
#      'reorderLevel': 0,
#      'discontinued': False}},
#    {'v_id': '21',
#     'v_type': 'Product',
#     'attributes': {'id': 21,
#      'productName': "Sir Rodney's Scones",
#      'qtyPerUnit': '24 pkgs. x 4 pieces',
#      'unitPrice': 10,
#      'inStock': 3,
#      'onOrder': 40,
#      'reorderLevel': 5,
#      'discontinued': False}},
#    {'v_id': '61',
#     'v_type': 'Product',
#     'attributes': {'id': 61,
#      'productName': "Sirop d'érable",
#      'qtyPerUnit': '24 - 500 ml bottles',
#      'unitPrice': 28.5,
#      'inStock': 113,
#      'onOrder': 0,
#      'reorderLevel': 25,
#      'discontinued': False}},
#    {'v_id': '46',
#     'v_type': 'Product',
#     'attributes': {'id': 46,
#      'productName': 'Spegesild',
#      'qtyPerUnit': '4 - 450 g glasses',
#      'unitPrice': 12,
#      'inStock': 95,
#      'onOrder': 0,
#      'reorderLevel': 0,
#      'discontinued': False}},
#    {'v_id': '35',
#     'v_type': 'Product',
#     'attributes': {'id': 35,
#      'productName': 'Steeleye Stout',
#      'qtyPerUnit': '24 - 12 oz bottles',
#      'unitPrice': 18,
#      'inStock': 20,
#      'onOrder': 0,
#      'reorderLevel': 15,
#      'discontinued': False}},
#    {'v_id': '62',
#     'v_type': 'Product',
#     'attributes': {'id': 62,
#      'productName': 'Tarte au sucre',
#      'qtyPerUnit': '48 pies',
#      'unitPrice': 49.3,
#      'inStock': 17,
#      'onOrder': 0,
#      'reorderLevel': 0,
#      'discontinued': False}},
#    {'v_id': '19',
#     'v_type': 'Product',
#     'attributes': {'id': 19,
#      'productName': 'Teatime Chocolate Biscuits',
#      'qtyPerUnit': '10 boxes x 12 pieces',
#      'unitPrice': 9.2,
#      'inStock': 25,
#      'onOrder': 0,
#      'reorderLevel': 5,
#      'discontinued': False}},
#    {'v_id': '29',
#     'v_type': 'Product',
#     'attributes': {'id': 29,
#      'productName': 'Thüringer Rostbratwurst',
#      'qtyPerUnit': '50 bags x 30 sausgs.',
#      'unitPrice': 123.79,
#      'inStock': 0,
#      'onOrder': 0,
#      'reorderLevel': 0,
#      'discontinued': True}},
#    {'v_id': '14',
#     'v_type': 'Product',
#     'attributes': {'id': 14,
#      'productName': 'Tofu',
#      'qtyPerUnit': '40 - 100 g pkgs.',
#      'unitPrice': 23.25,
#      'inStock': 35,
#      'onOrder': 0,
#      'reorderLevel': 0,
#      'discontinued': False}},
#    {'v_id': '54',
#     'v_type': 'Product',
#     'attributes': {'id': 54,
#      'productName': 'Tourtière',
#      'qtyPerUnit': '16 pies',
#      'unitPrice': 7.45,
#      'inStock': 21,
#      'onOrder': 0,
#      'reorderLevel': 10,
#      'discontinued': False}},
#    {'v_id': '23',
#     'v_type': 'Product',
#     'attributes': {'id': 23,
#      'productName': 'Tunnbröd',
#      'qtyPerUnit': '12 - 250 g pkgs.',
#      'unitPrice': 9,
#      'inStock': 61,
#      'onOrder': 0,
#      'reorderLevel': 25,
#      'discontinued': False}},
#    {'v_id': '7',
#     'v_type': 'Product',
#     'attributes': {'id': 7,
#      'productName': "Uncle Bob's Organic Dried Pears",
#      'qtyPerUnit': '12 - 1 lb pkgs.',
#      'unitPrice': 30,
#      'inStock': 15,
#      'onOrder': 0,
#      'reorderLevel': 10,
#      'discontinued': False}},
#    {'v_id': '50',
#     'v_type': 'Product',
#     'attributes': {'id': 50,
#      'productName': 'Valkoinen suklaa',
#      'qtyPerUnit': '12 - 100 g bars',
#      'unitPrice': 16.25,
#      'inStock': 65,
#      'onOrder': 0,
#      'reorderLevel': 30,
#      'discontinued': False}},
#    {'v_id': '63',
#     'v_type': 'Product',
#     'attributes': {'id': 63,
#      'productName': 'Vegie-spread',
#      'qtyPerUnit': '15 - 625 g jars',
#      'unitPrice': 43.9,
#      'inStock': 24,
#      'onOrder': 0,
#      'reorderLevel': 5,
#      'discontinued': False}},
#    {'v_id': '64',
#     'v_type': 'Product',
#     'attributes': {'id': 64,
#      'productName': 'Wimmers gute Semmelknödel',
#      'qtyPerUnit': '20 bags x 4 pieces',
#      'unitPrice': 33.25,
#      'inStock': 22,
#      'onOrder': 80,
#      'reorderLevel': 30,
#      'discontinued': False}},
#    {'v_id': '47',
#     'v_type': 'Product',
#     'attributes': {'id': 47,
#      'productName': 'Zaanse koeken',
#      'qtyPerUnit': '10 - 4 oz boxes',
#      'unitPrice': 9.5,
#      'inStock': 36,
#      'onOrder': 0,
#      'reorderLevel': 0,
#      'discontinued': False}}]}]

# %% [markdown]
# ### Current Products
# Get all products that aren't discontinued.

# %%
conn.runInterpretedQuery("""
INTERPRET QUERY get_current_product_list() FOR GRAPH Northwind { 
  
  products = {Product.*};
  
  results = SELECT p FROM products:p
    WHERE
      p.discontinued == FALSE
    ORDER BY
      p.productName ASC;
  
  PRINT results [results.id, results.productName];
}
""")
# Out:
# [{'results': [{'v_id': 'ProductID',
#     'v_type': 'Product',
#     'attributes': {'results.id': 0, 'results.productName': ''}},
#    {'v_id': '3',
#     'v_type': 'Product',
#     'attributes': {'results.id': 3, 'results.productName': 'Aniseed Syrup'}},
#    {'v_id': '40',
#     'v_type': 'Product',
#     'attributes': {'results.id': 40,
#      'results.productName': 'Boston Crab Meat'}},
#    {'v_id': '60',
#     'v_type': 'Product',
#     'attributes': {'results.id': 60,
#      'results.productName': 'Camembert Pierrot'}},
#    {'v_id': '18',
#     'v_type': 'Product',
#     'attributes': {'results.id': 18,
#      'results.productName': 'Carnarvon Tigers'}},
#    {'v_id': '1',
#     'v_type': 'Product',
#     'attributes': {'results.id': 1, 'results.productName': 'Chai'}},
#    {'v_id': '2',
#     'v_type': 'Product',
#     'attributes': {'results.id': 2, 'results.productName': 'Chang'}},
#    {'v_id': '39',
#     'v_type': 'Product',
#     'attributes': {'results.id': 39,
#      'results.productName': 'Chartreuse verte'}},
#    {'v_id': '4',
#     'v_type': 'Product',
#     'attributes': {'results.id': 4,
#      'results.productName': "Chef Anton's Cajun Seasoning"}},
#    {'v_id': '48',
#     'v_type': 'Product',
#     'attributes': {'results.id': 48, 'results.productName': 'Chocolade'}},
#    {'v_id': '38',
#     'v_type': 'Product',
#     'attributes': {'results.id': 38, 'results.productName': 'Côte de Blaye'}},
#    {'v_id': '58',
#     'v_type': 'Product',
#     'attributes': {'results.id': 58,
#      'results.productName': 'Escargots de Bourgogne'}},
#    {'v_id': '52',
#     'v_type': 'Product',
#     'attributes': {'results.id': 52, 'results.productName': 'Filo Mix'}},
#    {'v_id': '71',
#     'v_type': 'Product',
#     'attributes': {'results.id': 71, 'results.productName': 'Flotemysost'}},
#    {'v_id': '33',
#     'v_type': 'Product',
#     'attributes': {'results.id': 33, 'results.productName': 'Geitost'}},
#    {'v_id': '15',
#     'v_type': 'Product',
#     'attributes': {'results.id': 15, 'results.productName': 'Genen Shouyu'}},
#    {'v_id': '56',
#     'v_type': 'Product',
#     'attributes': {'results.id': 56,
#      'results.productName': 'Gnocchi di nonna Alice'}},
#    {'v_id': '31',
#     'v_type': 'Product',
#     'attributes': {'results.id': 31,
#      'results.productName': 'Gorgonzola Telino'}},
#    {'v_id': '6',
#     'v_type': 'Product',
#     'attributes': {'results.id': 6,
#      'results.productName': "Grandma's Boysenberry Spread"}},
#    {'v_id': '37',
#     'v_type': 'Product',
#     'attributes': {'results.id': 37, 'results.productName': 'Gravad lax'}},
#    {'v_id': '69',
#     'v_type': 'Product',
#     'attributes': {'results.id': 69,
#      'results.productName': 'Gudbrandsdalsost'}},
#    {'v_id': '44',
#     'v_type': 'Product',
#     'attributes': {'results.id': 44, 'results.productName': 'Gula Malacca'}},
#    {'v_id': '26',
#     'v_type': 'Product',
#     'attributes': {'results.id': 26,
#      'results.productName': 'Gumbär Gummibärchen'}},
#    {'v_id': '22',
#     'v_type': 'Product',
#     'attributes': {'results.id': 22,
#      'results.productName': "Gustaf's Knäckebröd"}},
#    {'v_id': '10',
#     'v_type': 'Product',
#     'attributes': {'results.id': 10, 'results.productName': 'Ikura'}},
#    {'v_id': '36',
#     'v_type': 'Product',
#     'attributes': {'results.id': 36, 'results.productName': 'Inlagd Sill'}},
#    {'v_id': '43',
#     'v_type': 'Product',
#     'attributes': {'results.id': 43, 'results.productName': 'Ipoh Coffee'}},
#    {'v_id': '41',
#     'v_type': 'Product',
#     'attributes': {'results.id': 41,
#      'results.productName': "Jack's New England Clam Chowder"}},
#    {'v_id': '13',
#     'v_type': 'Product',
#     'attributes': {'results.id': 13, 'results.productName': 'Konbu'}},
#    {'v_id': '76',
#     'v_type': 'Product',
#     'attributes': {'results.id': 76, 'results.productName': 'Lakkalikööri'}},
#    {'v_id': '67',
#     'v_type': 'Product',
#     'attributes': {'results.id': 67,
#      'results.productName': 'Laughing Lumberjack Lager'}},
#    {'v_id': '74',
#     'v_type': 'Product',
#     'attributes': {'results.id': 74, 'results.productName': 'Longlife Tofu'}},
#    {'v_id': '65',
#     'v_type': 'Product',
#     'attributes': {'results.id': 65,
#      'results.productName': 'Louisiana Fiery Hot Pepper Sauce'}},
#    {'v_id': '66',
#     'v_type': 'Product',
#     'attributes': {'results.id': 66,
#      'results.productName': 'Louisiana Hot Spiced Okra'}},
#    {'v_id': '51',
#     'v_type': 'Product',
#     'attributes': {'results.id': 51,
#      'results.productName': 'Manjimup Dried Apples'}},
#    {'v_id': '32',
#     'v_type': 'Product',
#     'attributes': {'results.id': 32,
#      'results.productName': 'Mascarpone Fabioli'}},
#    {'v_id': '49',
#     'v_type': 'Product',
#     'attributes': {'results.id': 49, 'results.productName': 'Maxilaku'}},
#    {'v_id': '72',
#     'v_type': 'Product',
#     'attributes': {'results.id': 72,
#      'results.productName': 'Mozzarella di Giovanni'}},
#    {'v_id': '30',
#     'v_type': 'Product',
#     'attributes': {'results.id': 30,
#      'results.productName': 'Nord-Ost Matjeshering'}},
#    {'v_id': '8',
#     'v_type': 'Product',
#     'attributes': {'results.id': 8,
#      'results.productName': 'Northwoods Cranberry Sauce'}},
#    {'v_id': '25',
#     'v_type': 'Product',
#     'attributes': {'results.id': 25,
#      'results.productName': 'NuNuCa Nuß-Nougat-Creme'}},
#    {'v_id': '77',
#     'v_type': 'Product',
#     'attributes': {'results.id': 77,
#      'results.productName': 'Original Frankfurter grüne Soße'}},
#    {'v_id': '70',
#     'v_type': 'Product',
#     'attributes': {'results.id': 70, 'results.productName': 'Outback Lager'}},
#    {'v_id': '16',
#     'v_type': 'Product',
#     'attributes': {'results.id': 16, 'results.productName': 'Pavlova'}},
#    {'v_id': '55',
#     'v_type': 'Product',
#     'attributes': {'results.id': 55, 'results.productName': 'Pâté chinois'}},
#    {'v_id': '11',
#     'v_type': 'Product',
#     'attributes': {'results.id': 11, 'results.productName': 'Queso Cabrales'}},
#    {'v_id': '12',
#     'v_type': 'Product',
#     'attributes': {'results.id': 12,
#      'results.productName': 'Queso Manchego La Pastora'}},
#    {'v_id': '59',
#     'v_type': 'Product',
#     'attributes': {'results.id': 59,
#      'results.productName': 'Raclette Courdavault'}},
#    {'v_id': '57',
#     'v_type': 'Product',
#     'attributes': {'results.id': 57, 'results.productName': 'Ravioli Angelo'}},
#    {'v_id': '75',
#     'v_type': 'Product',
#     'attributes': {'results.id': 75,
#      'results.productName': 'Rhönbräu Klosterbier'}},
#    {'v_id': '45',
#     'v_type': 'Product',
#     'attributes': {'results.id': 45, 'results.productName': 'Rogede sild'}},
#    {'v_id': '73',
#     'v_type': 'Product',
#     'attributes': {'results.id': 73, 'results.productName': 'Röd Kaviar'}},
#    {'v_id': '34',
#     'v_type': 'Product',
#     'attributes': {'results.id': 34, 'results.productName': 'Sasquatch Ale'}},
#    {'v_id': '27',
#     'v_type': 'Product',
#     'attributes': {'results.id': 27,
#      'results.productName': 'Schoggi Schokolade'}},
#    {'v_id': '68',
#     'v_type': 'Product',
#     'attributes': {'results.id': 68,
#      'results.productName': 'Scottish Longbreads'}},
#    {'v_id': '20',
#     'v_type': 'Product',
#     'attributes': {'results.id': 20,
#      'results.productName': "Sir Rodney's Marmalade"}},
#    {'v_id': '21',
#     'v_type': 'Product',
#     'attributes': {'results.id': 21,
#      'results.productName': "Sir Rodney's Scones"}},
#    {'v_id': '61',
#     'v_type': 'Product',
#     'attributes': {'results.id': 61, 'results.productName': "Sirop d'érable"}},
#    {'v_id': '46',
#     'v_type': 'Product',
#     'attributes': {'results.id': 46, 'results.productName': 'Spegesild'}},
#    {'v_id': '35',
#     'v_type': 'Product',
#     'attributes': {'results.id': 35, 'results.productName': 'Steeleye Stout'}},
#    {'v_id': '62',
#     'v_type': 'Product',
#     'attributes': {'results.id': 62, 'results.productName': 'Tarte au sucre'}},
#    {'v_id': '19',
#     'v_type': 'Product',
#     'attributes': {'results.id': 19,
#      'results.productName': 'Teatime Chocolate Biscuits'}},
#    {'v_id': '14',
#     'v_type': 'Product',
#     'attributes': {'results.id': 14, 'results.productName': 'Tofu'}},
#    {'v_id': '54',
#     'v_type': 'Product',
#     'attributes': {'results.id': 54, 'results.productName': 'Tourtière'}},
#    {'v_id': '23',
#     'v_type': 'Product',
#     'attributes': {'results.id': 23, 'results.productName': 'Tunnbröd'}},
#    {'v_id': '7',
#     'v_type': 'Product',
#     'attributes': {'results.id': 7,
#      'results.productName': "Uncle Bob's Organic Dried Pears"}},
#    {'v_id': '50',
#     'v_type': 'Product',
#     'attributes': {'results.id': 50,
#      'results.productName': 'Valkoinen suklaa'}},
#    {'v_id': '63',
#     'v_type': 'Product',
#     'attributes': {'results.id': 63, 'results.productName': 'Vegie-spread'}},
#    {'v_id': '64',
#     'v_type': 'Product',
#     'attributes': {'results.id': 64,
#      'results.productName': 'Wimmers gute Semmelknödel'}},
#    {'v_id': '47',
#     'v_type': 'Product',
#     'attributes': {'results.id': 47,
#      'results.productName': 'Zaanse koeken'}}]}]

# %% [markdown]
# ### Extended Order Details
# Get the details of each product for each order.

# %%
conn.runInterpretedQuery("""
INTERPRET QUERY get_order_details_extended() FOR GRAPH Northwind { 
  TYPEDEF TUPLE <INT product_id, STRING product_name, FLOAT unit_price, INT qty, FLOAT discnt, FLOAT ext_price> product_details;
  c_order = {CustomerOrder.*};
  
  MapAccum<VERTEX<Product>, product_details> @extended_price;
  
  results = SELECT o FROM c_order:o - (:e) - Product:p
    ACCUM
      FLOAT extended_price = e.unitPrice * e.quantity * (1 - e.discount),
      o.@extended_price += (p -> product_details(p.id, p.productName, e.unitPrice, e.quantity, e.discount, extended_price))
    ORDER BY
      o.id ASC;
  
  PRINT results [results.id, results.@extended_price];
}
""")
# Out:
# [{'results': [{'v_id': '11074',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 0,
#      'results.@extended_price': {'16': {'product_id': 16,
#        'product_name': 'Pavlova',
#        'unit_price': 17.45,
#        'qty': 14,
#        'discnt': 0.05,
#        'ext_price': 232.08502}}}},
#    {'v_id': '11062',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 0,
#      'results.@extended_price': {'53': {'product_id': 53,
#        'product_name': 'Perth Pasties',
#        'unit_price': 32.8,
#        'qty': 10,
#        'discnt': 0.2,
#        'ext_price': 262.39999},
#       '70': {'product_id': 70,
#        'product_name': 'Outback Lager',
#        'unit_price': 15,
#        'qty': 12,
#        'discnt': 0.2,
#        'ext_price': 144}}}},
#    {'v_id': '11077',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 0,
#      'results.@extended_price': {'20': {'product_id': 20,
#        'product_name': "Sir Rodney's Marmalade",
#        'unit_price': 81,
#        'qty': 1,
#        'discnt': 0.04,
#        'ext_price': 77.76},
#       '7': {'product_id': 7,
#        'product_name': "Uncle Bob's Organic Dried Pears",
#        'unit_price': 30,
#        'qty': 1,
#        'discnt': 0.05,
#        'ext_price': 28.5},
#       '55': {'product_id': 55,
#        'product_name': 'Pâté chinois',
#        'unit_price': 24,
#        'qty': 2,
#        'discnt': 0,
#        'ext_price': 48},
#       '66': {'product_id': 66,
#        'product_name': 'Louisiana Hot Spiced Okra',
#        'unit_price': 17,
#        'qty': 1,
#        'discnt': 0,
#        'ext_price': 17},
#       '75': {'product_id': 75,
#        'product_name': 'Rhönbräu Klosterbier',
#        'unit_price': 7.75,
#        'qty': 4,
#        'discnt': 0,
#        'ext_price': 31},
#       '39': {'product_id': 39,
#        'product_name': 'Chartreuse verte',
#        'unit_price': 18,
#        'qty': 2,
#        'discnt': 0.05,
#        'ext_price': 34.2},
#       '12': {'product_id': 12,
#        'product_name': 'Queso Manchego La Pastora',
#        'unit_price': 38,
#        'qty': 2,
#        'discnt': 0.05,
#        'ext_price': 72.2},
#       '41': {'product_id': 41,
#        'product_name': "Jack's New England Clam Chowder",
#        'unit_price': 9.65,
#        'qty': 3,
#        'discnt': 0,
#        'ext_price': 28.95},
#       '64': {'product_id': 64,
#        'product_name': 'Wimmers gute Semmelknödel',
#        'unit_price': 33.25,
#        'qty': 2,
#        'discnt': 0.03,
#        'ext_price': 64.505},
#       '6': {'product_id': 6,
#        'product_name': "Grandma's Boysenberry Spread",
#        'unit_price': 25,
#        'qty': 1,
#        'discnt': 0.02,
#        'ext_price': 24.5},
#       '16': {'product_id': 16,
#        'product_name': 'Pavlova',
#        'unit_price': 17.45,
#        'qty': 2,
#        'discnt': 0.03,
#        'ext_price': 33.853},
#       '2': {'product_id': 2,
#        'product_name': 'Chang',
#        'unit_price': 19,
#        'qty': 24,
#        'discnt': 0.2,
#        'ext_price': 364.79999},
#       '60': {'product_id': 60,
#        'product_name': 'Camembert Pierrot',
#        'unit_price': 34,
#        'qty': 2,
#        'discnt': 0.06,
#        'ext_price': 63.92},
#       '52': {'product_id': 52,
#        'product_name': 'Filo Mix',
#        'unit_price': 7,
#        'qty': 2,
#        'discnt': 0,
#        'ext_price': 14},
#       '13': {'product_id': 13,
#        'product_name': 'Konbu',
#        'unit_price': 6,
#        'qty': 4,
#        'discnt': 0,
#        'ext_price': 24},
#       '23': {'product_id': 23,
#        'product_name': 'Tunnbröd',
#        'unit_price': 9,
#        'qty': 2,
#        'discnt': 0,
#        'ext_price': 18},
#       '3': {'product_id': 3,
#        'product_name': 'Aniseed Syrup',
#        'unit_price': 10,
#        'qty': 4,
#        'discnt': 0,
#        'ext_price': 40},
#       '14': {'product_id': 14,
#        'product_name': 'Tofu',
#        'unit_price': 23.25,
#        'qty': 1,
#        'discnt': 0.03,
#        'ext_price': 22.5525},
#       '4': {'product_id': 4,
#        'product_name': "Chef Anton's Cajun Seasoning",
#        'unit_price': 22,
#        'qty': 1,
#        'discnt': 0,
#        'ext_price': 22},
#       '73': {'product_id': 73,
#        'product_name': 'Röd Kaviar',
#        'unit_price': 15,
#        'qty': 2,
#        'discnt': 0.01,
#        'ext_price': 29.7},
#       '8': {'product_id': 8,
#        'product_name': 'Northwoods Cranberry Sauce',
#        'unit_price': 40,
#        'qty': 2,
#        'discnt': 0.1,
#        'ext_price': 72},
#       '77': {'product_id': 77,
#        'product_name': 'Original Frankfurter grüne Soße',
#        'unit_price': 13,
#        'qty': 2,
#        'discnt': 0,
#        'ext_price': 26},
#       '10': {'product_id': 10,
#        'product_name': 'Ikura',
#        'unit_price': 31,
#        'qty': 1,
#        'discnt': 0,
#        'ext_price': 31},
#       '32': {'product_id': 32,
#        'product_name': 'Mascarpone Fabioli',
#        'unit_price': 32,
#        'qty': 1,
#        'discnt': 0,
#        'ext_price': 32},
#       '46': {'product_id': 46,
#        'product_name': 'Spegesild',
#        'unit_price': 12,
#        'qty': 3,
#        'discnt': 0.02,
#        'ext_price': 35.28}}}},
#    {'v_id': '11070',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 0,
#      'results.@extended_price': {'1': {'product_id': 1,
#        'product_name': 'Chai',
#        'unit_price': 18,
#        'qty': 40,
#        'discnt': 0.15,
#        'ext_price': 612},
#       '2': {'product_id': 2,
#        'product_name': 'Chang',
#        'unit_price': 19,
#        'qty': 20,
#        'discnt': 0.15,
#        'ext_price': 323},
#       '16': {'product_id': 16,
#        'product_name': 'Pavlova',
#        'unit_price': 17.45,
#        'qty': 30,
#        'discnt': 0.15,
#        'ext_price': 444.97501},
#       '31': {'product_id': 31,
#        'product_name': 'Gorgonzola Telino',
#        'unit_price': 12.5,
#        'qty': 20,
#        'discnt': 0,
#        'ext_price': 250}}}},
#    {'v_id': '11059',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 0,
#      'results.@extended_price': {'17': {'product_id': 17,
#        'product_name': 'Alice Mutton',
#        'unit_price': 39,
#        'qty': 12,
#        'discnt': 0,
#        'ext_price': 468},
#       '13': {'product_id': 13,
#        'product_name': 'Konbu',
#        'unit_price': 6,
#        'qty': 30,
#        'discnt': 0,
#        'ext_price': 180},
#       '60': {'product_id': 60,
#        'product_name': 'Camembert Pierrot',
#        'unit_price': 34,
#        'qty': 35,
#        'discnt': 0,
#        'ext_price': 1190}}}},
#    {'v_id': '11061',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 0,
#      'results.@extended_price': {'60': {'product_id': 60,
#        'product_name': 'Camembert Pierrot',
#        'unit_price': 34,
#        'qty': 15,
#        'discnt': 0,
#        'ext_price': 510}}}},
#    {'v_id': '11051',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 0,
#      'results.@extended_price': {'24': {'product_id': 24,
#        'product_name': 'Guaraná Fantástica',
#        'unit_price': 4.5,
#        'qty': 10,
#        'discnt': 0.2,
#        'ext_price': 36}}}},
#    {'v_id': '11040',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 0,
#      'results.@extended_price': {'21': {'product_id': 21,
#        'product_name': "Sir Rodney's Scones",
#        'unit_price': 10,
#        'qty': 20,
#        'discnt': 0,
#        'ext_price': 200}}}},
#    {'v_id': '11058',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 0,
#      'results.@extended_price': {'21': {'product_id': 21,
#        'product_name': "Sir Rodney's Scones",
#        'unit_price': 10,
#        'qty': 3,
#        'discnt': 0,
#        'ext_price': 30},
#       '61': {'product_id': 61,
#        'product_name': "Sirop d'érable",
#        'unit_price': 28.5,
#        'qty': 4,
#        'discnt': 0,
#        'ext_price': 114},
#       '60': {'product_id': 60,
#        'product_name': 'Camembert Pierrot',
#        'unit_price': 34,
#        'qty': 21,
#        'discnt': 0,
#        'ext_price': 714}}}},
#    {'v_id': '11068',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 0,
#      'results.@extended_price': {'77': {'product_id': 77,
#        'product_name': 'Original Frankfurter grüne Soße',
#        'unit_price': 13,
#        'qty': 28,
#        'discnt': 0.15,
#        'ext_price': 309.39999},
#       '28': {'product_id': 28,
#        'product_name': 'Rössle Sauerkraut',
#        'unit_price': 45.6,
#        'qty': 8,
#        'discnt': 0.15,
#        'ext_price': 310.07999},
#       '43': {'product_id': 43,
#        'product_name': 'Ipoh Coffee',
#        'unit_price': 46,
#        'qty': 36,
#        'discnt': 0.15,
#        'ext_price': 1407.59998}}}},
#    {'v_id': '11073',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 0,
#      'results.@extended_price': {'24': {'product_id': 24,
#        'product_name': 'Guaraná Fantástica',
#        'unit_price': 4.5,
#        'qty': 20,
#        'discnt': 0,
#        'ext_price': 90},
#       '11': {'product_id': 11,
#        'product_name': 'Queso Cabrales',
#        'unit_price': 21,
#        'qty': 10,
#        'discnt': 0,
#        'ext_price': 210}}}},
#    {'v_id': '11075',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 0,
#      'results.@extended_price': {'2': {'product_id': 2,
#        'product_name': 'Chang',
#        'unit_price': 19,
#        'qty': 10,
#        'discnt': 0.15,
#        'ext_price': 161.5},
#       '46': {'product_id': 46,
#        'product_name': 'Spegesild',
#        'unit_price': 12,
#        'qty': 30,
#        'discnt': 0.15,
#        'ext_price': 306},
#       '76': {'product_id': 76,
#        'product_name': 'Lakkalikööri',
#        'unit_price': 18,
#        'qty': 2,
#        'discnt': 0.15,
#        'ext_price': 30.6}}}},
#    {'v_id': '11054',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 0,
#      'results.@extended_price': {'67': {'product_id': 67,
#        'product_name': 'Laughing Lumberjack Lager',
#        'unit_price': 14,
#        'qty': 20,
#        'discnt': 0,
#        'ext_price': 280},
#       '33': {'product_id': 33,
#        'product_name': 'Geitost',
#        'unit_price': 2.5,
#        'qty': 10,
#        'discnt': 0,
#        'ext_price': 25}}}},
#    {'v_id': '11072',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 0,
#      'results.@extended_price': {'2': {'product_id': 2,
#        'product_name': 'Chang',
#        'unit_price': 19,
#        'qty': 8,
#        'discnt': 0,
#        'ext_price': 152},
#       '41': {'product_id': 41,
#        'product_name': "Jack's New England Clam Chowder",
#        'unit_price': 9.65,
#        'qty': 40,
#        'discnt': 0,
#        'ext_price': 386},
#       '50': {'product_id': 50,
#        'product_name': 'Valkoinen suklaa',
#        'unit_price': 16.25,
#        'qty': 22,
#        'discnt': 0,
#        'ext_price': 357.5},
#       '64': {'product_id': 64,
#        'product_name': 'Wimmers gute Semmelknödel',
#        'unit_price': 33.25,
#        'qty': 130,
#        'discnt': 0,
#        'ext_price': 4322.5}}}},
#    {'v_id': '11065',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 0,
#      'results.@extended_price': {'54': {'product_id': 54,
#        'product_name': 'Tourtière',
#        'unit_price': 7.45,
#        'qty': 20,
#        'discnt': 0.25,
#        'ext_price': 111.75},
#       '30': {'product_id': 30,
#        'product_name': 'Nord-Ost Matjeshering',
#        'unit_price': 25.89,
#        'qty': 4,
#        'discnt': 0.25,
#        'ext_price': 77.67}}}},
#    {'v_id': '11045',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 0,
#      'results.@extended_price': {'51': {'product_id': 51,
#        'product_name': 'Manjimup Dried Apples',
#        'unit_price': 53,
#        'qty': 24,
#        'discnt': 0,
#        'ext_price': 1272},
#       '33': {'product_id': 33,
#        'product_name': 'Geitost',
#        'unit_price': 2.5,
#        'qty': 15,
#        'discnt': 0,
#        'ext_price': 37.5}}}},
#    {'v_id': '11019',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 0,
#      'results.@extended_price': {'46': {'product_id': 46,
#        'product_name': 'Spegesild',
#        'unit_price': 12,
#        'qty': 3,
#        'discnt': 0,
#        'ext_price': 36},
#       '49': {'product_id': 49,
#        'product_name': 'Maxilaku',
#        'unit_price': 20,
#        'qty': 2,
#        'discnt': 0,
#        'ext_price': 40}}}},
#    {'v_id': '11071',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 0,
#      'results.@extended_price': {'13': {'product_id': 13,
#        'product_name': 'Konbu',
#        'unit_price': 6,
#        'qty': 10,
#        'discnt': 0.05,
#        'ext_price': 57},
#       '7': {'product_id': 7,
#        'product_name': "Uncle Bob's Organic Dried Pears",
#        'unit_price': 30,
#        'qty': 15,
#        'discnt': 0.05,
#        'ext_price': 427.5}}}},
#    {'v_id': '11076',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 0,
#      'results.@extended_price': {'14': {'product_id': 14,
#        'product_name': 'Tofu',
#        'unit_price': 23.25,
#        'qty': 20,
#        'discnt': 0.25,
#        'ext_price': 348.75},
#       '6': {'product_id': 6,
#        'product_name': "Grandma's Boysenberry Spread",
#        'unit_price': 25,
#        'qty': 20,
#        'discnt': 0.25,
#        'ext_price': 375},
#       '19': {'product_id': 19,
#        'product_name': 'Teatime Chocolate Biscuits',
#        'unit_price': 9.2,
#        'qty': 10,
#        'discnt': 0.25,
#        'ext_price': 69}}}},
#    {'v_id': '11039',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 0,
#      'results.@extended_price': {'35': {'product_id': 35,
#        'product_name': 'Steeleye Stout',
#        'unit_price': 18,
#        'qty': 24,
#        'discnt': 0,
#        'ext_price': 432},
#       '57': {'product_id': 57,
#        'product_name': 'Ravioli Angelo',
#        'unit_price': 19.5,
#        'qty': 28,
#        'discnt': 0,
#        'ext_price': 546},
#       '49': {'product_id': 49,
#        'product_name': 'Maxilaku',
#        'unit_price': 20,
#        'qty': 60,
#        'discnt': 0,
#        'ext_price': 1200},
#       '28': {'product_id': 28,
#        'product_name': 'Rössle Sauerkraut',
#        'unit_price': 45.6,
#        'qty': 20,
#        'discnt': 0,
#        'ext_price': 912}}}},
#    {'v_id': '11008',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 0,
#      'results.@extended_price': {'34': {'product_id': 34,
#        'product_name': 'Sasquatch Ale',
#        'unit_price': 14,
#        'qty': 90,
#        'discnt': 0.05,
#        'ext_price': 1197},
#       '28': {'product_id': 28,
#        'product_name': 'Rössle Sauerkraut',
#        'unit_price': 45.6,
#        'qty': 70,
#        'discnt': 0.05,
#        'ext_price': 3032.3999},
#       '71': {'product_id': 71,
#        'product_name': 'Flotemysost',
#        'unit_price': 21.5,
#        'qty': 21,
#        'discnt': 0,
#        'ext_price': 451.5}}}},
#    {'v_id': '10248',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10248,
#      'results.@extended_price': {'72': {'product_id': 72,
#        'product_name': 'Mozzarella di Giovanni',
#        'unit_price': 34.8,
#        'qty': 5,
#        'discnt': 0,
#        'ext_price': 174},
#       '11': {'product_id': 11,
#        'product_name': 'Queso Cabrales',
#        'unit_price': 14,
#        'qty': 12,
#        'discnt': 0,
#        'ext_price': 168},
#       '42': {'product_id': 42,
#        'product_name': 'Singaporean Hokkien Fried Mee',
#        'unit_price': 9.8,
#        'qty': 10,
#        'discnt': 0,
#        'ext_price': 98}}}},
#    {'v_id': '10249',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10249,
#      'results.@extended_price': {'51': {'product_id': 51,
#        'product_name': 'Manjimup Dried Apples',
#        'unit_price': 42.4,
#        'qty': 40,
#        'discnt': 0,
#        'ext_price': 1696},
#       '14': {'product_id': 14,
#        'product_name': 'Tofu',
#        'unit_price': 18.6,
#        'qty': 9,
#        'discnt': 0,
#        'ext_price': 167.40001}}}},
#    {'v_id': '10250',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10250,
#      'results.@extended_price': {'41': {'product_id': 41,
#        'product_name': "Jack's New England Clam Chowder",
#        'unit_price': 7.7,
#        'qty': 10,
#        'discnt': 0,
#        'ext_price': 77},
#       '51': {'product_id': 51,
#        'product_name': 'Manjimup Dried Apples',
#        'unit_price': 42.4,
#        'qty': 35,
#        'discnt': 0.15,
#        'ext_price': 1261.40002},
#       '65': {'product_id': 65,
#        'product_name': 'Louisiana Fiery Hot Pepper Sauce',
#        'unit_price': 16.8,
#        'qty': 15,
#        'discnt': 0.15,
#        'ext_price': 214.19998}}}},
#    {'v_id': '10251',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10251,
#      'results.@extended_price': {'65': {'product_id': 65,
#        'product_name': 'Louisiana Fiery Hot Pepper Sauce',
#        'unit_price': 16.8,
#        'qty': 20,
#        'discnt': 0,
#        'ext_price': 336},
#       '22': {'product_id': 22,
#        'product_name': "Gustaf's Knäckebröd",
#        'unit_price': 16.8,
#        'qty': 6,
#        'discnt': 0.05,
#        'ext_price': 95.75999},
#       '57': {'product_id': 57,
#        'product_name': 'Ravioli Angelo',
#        'unit_price': 15.6,
#        'qty': 15,
#        'discnt': 0.05,
#        'ext_price': 222.3}}}},
#    {'v_id': '10252',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10252,
#      'results.@extended_price': {'33': {'product_id': 33,
#        'product_name': 'Geitost',
#        'unit_price': 2,
#        'qty': 25,
#        'discnt': 0.05,
#        'ext_price': 47.5},
#       '20': {'product_id': 20,
#        'product_name': "Sir Rodney's Marmalade",
#        'unit_price': 64.8,
#        'qty': 40,
#        'discnt': 0.05,
#        'ext_price': 2462.3999},
#       '60': {'product_id': 60,
#        'product_name': 'Camembert Pierrot',
#        'unit_price': 27.2,
#        'qty': 40,
#        'discnt': 0,
#        'ext_price': 1088}}}},
#    {'v_id': '10253',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10253,
#      'results.@extended_price': {'31': {'product_id': 31,
#        'product_name': 'Gorgonzola Telino',
#        'unit_price': 10,
#        'qty': 20,
#        'discnt': 0,
#        'ext_price': 200},
#       '49': {'product_id': 49,
#        'product_name': 'Maxilaku',
#        'unit_price': 16,
#        'qty': 40,
#        'discnt': 0,
#        'ext_price': 640},
#       '39': {'product_id': 39,
#        'product_name': 'Chartreuse verte',
#        'unit_price': 14.4,
#        'qty': 42,
#        'discnt': 0,
#        'ext_price': 604.79999}}}},
#    {'v_id': '10254',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10254,
#      'results.@extended_price': {'74': {'product_id': 74,
#        'product_name': 'Longlife Tofu',
#        'unit_price': 8,
#        'qty': 21,
#        'discnt': 0,
#        'ext_price': 168},
#       '24': {'product_id': 24,
#        'product_name': 'Guaraná Fantástica',
#        'unit_price': 3.6,
#        'qty': 15,
#        'discnt': 0.15,
#        'ext_price': 45.9},
#       '55': {'product_id': 55,
#        'product_name': 'Pâté chinois',
#        'unit_price': 19.2,
#        'qty': 21,
#        'discnt': 0.15,
#        'ext_price': 342.72}}}},
#    {'v_id': '10255',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10255,
#      'results.@extended_price': {'59': {'product_id': 59,
#        'product_name': 'Raclette Courdavault',
#        'unit_price': 44,
#        'qty': 30,
#        'discnt': 0,
#        'ext_price': 1320},
#       '2': {'product_id': 2,
#        'product_name': 'Chang',
#        'unit_price': 15.2,
#        'qty': 20,
#        'discnt': 0,
#        'ext_price': 304},
#       '16': {'product_id': 16,
#        'product_name': 'Pavlova',
#        'unit_price': 13.9,
#        'qty': 35,
#        'discnt': 0,
#        'ext_price': 486.5},
#       '36': {'product_id': 36,
#        'product_name': 'Inlagd Sill',
#        'unit_price': 15.2,
#        'qty': 25,
#        'discnt': 0,
#        'ext_price': 380}}}},
#    {'v_id': '10256',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10256,
#      'results.@extended_price': {'53': {'product_id': 53,
#        'product_name': 'Perth Pasties',
#        'unit_price': 26.2,
#        'qty': 15,
#        'discnt': 0,
#        'ext_price': 393},
#       '77': {'product_id': 77,
#        'product_name': 'Original Frankfurter grüne Soße',
#        'unit_price': 10.4,
#        'qty': 12,
#        'discnt': 0,
#        'ext_price': 124.8}}}},
#    {'v_id': '10257',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10257,
#      'results.@extended_price': {'27': {'product_id': 27,
#        'product_name': 'Schoggi Schokolade',
#        'unit_price': 35.1,
#        'qty': 25,
#        'discnt': 0,
#        'ext_price': 877.49994},
#       '77': {'product_id': 77,
#        'product_name': 'Original Frankfurter grüne Soße',
#        'unit_price': 10.4,
#        'qty': 15,
#        'discnt': 0,
#        'ext_price': 156},
#       '39': {'product_id': 39,
#        'product_name': 'Chartreuse verte',
#        'unit_price': 14.4,
#        'qty': 6,
#        'discnt': 0,
#        'ext_price': 86.39999}}}},
#    {'v_id': '10258',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10258,
#      'results.@extended_price': {'5': {'product_id': 5,
#        'product_name': "Chef Anton's Gumbo Mix",
#        'unit_price': 17,
#        'qty': 65,
#        'discnt': 0.2,
#        'ext_price': 884},
#       '2': {'product_id': 2,
#        'product_name': 'Chang',
#        'unit_price': 15.2,
#        'qty': 50,
#        'discnt': 0.2,
#        'ext_price': 608},
#       '32': {'product_id': 32,
#        'product_name': 'Mascarpone Fabioli',
#        'unit_price': 25.6,
#        'qty': 6,
#        'discnt': 0.2,
#        'ext_price': 122.88}}}},
#    {'v_id': '10259',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10259,
#      'results.@extended_price': {'21': {'product_id': 21,
#        'product_name': "Sir Rodney's Scones",
#        'unit_price': 8,
#        'qty': 10,
#        'discnt': 0,
#        'ext_price': 80},
#       '37': {'product_id': 37,
#        'product_name': 'Gravad lax',
#        'unit_price': 20.8,
#        'qty': 1,
#        'discnt': 0,
#        'ext_price': 20.8}}}},
#    {'v_id': '10260',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10260,
#      'results.@extended_price': {'41': {'product_id': 41,
#        'product_name': "Jack's New England Clam Chowder",
#        'unit_price': 7.7,
#        'qty': 16,
#        'discnt': 0.25,
#        'ext_price': 92.39999},
#       '57': {'product_id': 57,
#        'product_name': 'Ravioli Angelo',
#        'unit_price': 15.6,
#        'qty': 50,
#        'discnt': 0,
#        'ext_price': 780},
#       '62': {'product_id': 62,
#        'product_name': 'Tarte au sucre',
#        'unit_price': 39.4,
#        'qty': 15,
#        'discnt': 0.25,
#        'ext_price': 443.25},
#       '70': {'product_id': 70,
#        'product_name': 'Outback Lager',
#        'unit_price': 12,
#        'qty': 21,
#        'discnt': 0.25,
#        'ext_price': 189}}}},
#    {'v_id': '10261',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10261,
#      'results.@extended_price': {'21': {'product_id': 21,
#        'product_name': "Sir Rodney's Scones",
#        'unit_price': 8,
#        'qty': 20,
#        'discnt': 0,
#        'ext_price': 160},
#       '35': {'product_id': 35,
#        'product_name': 'Steeleye Stout',
#        'unit_price': 14.4,
#        'qty': 20,
#        'discnt': 0,
#        'ext_price': 288}}}},
#    {'v_id': '10262',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10262,
#      'results.@extended_price': {'5': {'product_id': 5,
#        'product_name': "Chef Anton's Gumbo Mix",
#        'unit_price': 17,
#        'qty': 12,
#        'discnt': 0.2,
#        'ext_price': 163.2},
#       '56': {'product_id': 56,
#        'product_name': 'Gnocchi di nonna Alice',
#        'unit_price': 30.4,
#        'qty': 2,
#        'discnt': 0,
#        'ext_price': 60.8},
#       '7': {'product_id': 7,
#        'product_name': "Uncle Bob's Organic Dried Pears",
#        'unit_price': 24,
#        'qty': 15,
#        'discnt': 0,
#        'ext_price': 360}}}},
#    {'v_id': '10263',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10263,
#      'results.@extended_price': {'24': {'product_id': 24,
#        'product_name': 'Guaraná Fantástica',
#        'unit_price': 3.6,
#        'qty': 28,
#        'discnt': 0,
#        'ext_price': 100.8},
#       '74': {'product_id': 74,
#        'product_name': 'Longlife Tofu',
#        'unit_price': 8,
#        'qty': 36,
#        'discnt': 0.25,
#        'ext_price': 216},
#       '16': {'product_id': 16,
#        'product_name': 'Pavlova',
#        'unit_price': 13.9,
#        'qty': 60,
#        'discnt': 0.25,
#        'ext_price': 625.5},
#       '30': {'product_id': 30,
#        'product_name': 'Nord-Ost Matjeshering',
#        'unit_price': 20.7,
#        'qty': 60,
#        'discnt': 0.25,
#        'ext_price': 931.5}}}},
#    {'v_id': '10264',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10264,
#      'results.@extended_price': {'2': {'product_id': 2,
#        'product_name': 'Chang',
#        'unit_price': 15.2,
#        'qty': 35,
#        'discnt': 0,
#        'ext_price': 532},
#       '41': {'product_id': 41,
#        'product_name': "Jack's New England Clam Chowder",
#        'unit_price': 7.7,
#        'qty': 25,
#        'discnt': 0.15,
#        'ext_price': 163.625}}}},
#    {'v_id': '10265',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10265,
#      'results.@extended_price': {'17': {'product_id': 17,
#        'product_name': 'Alice Mutton',
#        'unit_price': 31.2,
#        'qty': 30,
#        'discnt': 0,
#        'ext_price': 936},
#       '70': {'product_id': 70,
#        'product_name': 'Outback Lager',
#        'unit_price': 12,
#        'qty': 20,
#        'discnt': 0,
#        'ext_price': 240}}}},
#    {'v_id': '10266',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10266,
#      'results.@extended_price': {'12': {'product_id': 12,
#        'product_name': 'Queso Manchego La Pastora',
#        'unit_price': 30.4,
#        'qty': 12,
#        'discnt': 0.05,
#        'ext_price': 346.56}}}},
#    {'v_id': '10267',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10267,
#      'results.@extended_price': {'59': {'product_id': 59,
#        'product_name': 'Raclette Courdavault',
#        'unit_price': 44,
#        'qty': 70,
#        'discnt': 0.15,
#        'ext_price': 2618},
#       '76': {'product_id': 76,
#        'product_name': 'Lakkalikööri',
#        'unit_price': 14.4,
#        'qty': 15,
#        'discnt': 0.15,
#        'ext_price': 183.60001},
#       '40': {'product_id': 40,
#        'product_name': 'Boston Crab Meat',
#        'unit_price': 14.7,
#        'qty': 50,
#        'discnt': 0,
#        'ext_price': 735}}}},
#    {'v_id': '10268',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10268,
#      'results.@extended_price': {'29': {'product_id': 29,
#        'product_name': 'Thüringer Rostbratwurst',
#        'unit_price': 99,
#        'qty': 10,
#        'discnt': 0,
#        'ext_price': 990},
#       '72': {'product_id': 72,
#        'product_name': 'Mozzarella di Giovanni',
#        'unit_price': 27.8,
#        'qty': 4,
#        'discnt': 0,
#        'ext_price': 111.2}}}},
#    {'v_id': '10269',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10269,
#      'results.@extended_price': {'72': {'product_id': 72,
#        'product_name': 'Mozzarella di Giovanni',
#        'unit_price': 27.8,
#        'qty': 20,
#        'discnt': 0.05,
#        'ext_price': 528.20001},
#       '33': {'product_id': 33,
#        'product_name': 'Geitost',
#        'unit_price': 2,
#        'qty': 60,
#        'discnt': 0.05,
#        'ext_price': 114}}}},
#    {'v_id': '10270',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10270,
#      'results.@extended_price': {'36': {'product_id': 36,
#        'product_name': 'Inlagd Sill',
#        'unit_price': 15.2,
#        'qty': 30,
#        'discnt': 0,
#        'ext_price': 456},
#       '43': {'product_id': 43,
#        'product_name': 'Ipoh Coffee',
#        'unit_price': 36.8,
#        'qty': 25,
#        'discnt': 0,
#        'ext_price': 920}}}},
#    {'v_id': '10271',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10271,
#      'results.@extended_price': {'33': {'product_id': 33,
#        'product_name': 'Geitost',
#        'unit_price': 2,
#        'qty': 24,
#        'discnt': 0,
#        'ext_price': 48}}}},
#    {'v_id': '10272',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10272,
#      'results.@extended_price': {'31': {'product_id': 31,
#        'product_name': 'Gorgonzola Telino',
#        'unit_price': 10,
#        'qty': 40,
#        'discnt': 0,
#        'ext_price': 400},
#       '72': {'product_id': 72,
#        'product_name': 'Mozzarella di Giovanni',
#        'unit_price': 27.8,
#        'qty': 24,
#        'discnt': 0,
#        'ext_price': 667.19995},
#       '20': {'product_id': 20,
#        'product_name': "Sir Rodney's Marmalade",
#        'unit_price': 64.8,
#        'qty': 6,
#        'discnt': 0,
#        'ext_price': 388.80002}}}},
#    {'v_id': '10273',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10273,
#      'results.@extended_price': {'10': {'product_id': 10,
#        'product_name': 'Ikura',
#        'unit_price': 24.8,
#        'qty': 24,
#        'discnt': 0.05,
#        'ext_price': 565.43994},
#       '76': {'product_id': 76,
#        'product_name': 'Lakkalikööri',
#        'unit_price': 14.4,
#        'qty': 33,
#        'discnt': 0.05,
#        'ext_price': 451.43997},
#       '33': {'product_id': 33,
#        'product_name': 'Geitost',
#        'unit_price': 2,
#        'qty': 20,
#        'discnt': 0,
#        'ext_price': 40},
#       '31': {'product_id': 31,
#        'product_name': 'Gorgonzola Telino',
#        'unit_price': 10,
#        'qty': 15,
#        'discnt': 0.05,
#        'ext_price': 142.5},
#       '40': {'product_id': 40,
#        'product_name': 'Boston Crab Meat',
#        'unit_price': 14.7,
#        'qty': 60,
#        'discnt': 0.05,
#        'ext_price': 837.90002}}}},
#    {'v_id': '10274',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10274,
#      'results.@extended_price': {'72': {'product_id': 72,
#        'product_name': 'Mozzarella di Giovanni',
#        'unit_price': 27.8,
#        'qty': 7,
#        'discnt': 0,
#        'ext_price': 194.59999},
#       '71': {'product_id': 71,
#        'product_name': 'Flotemysost',
#        'unit_price': 17.2,
#        'qty': 20,
#        'discnt': 0,
#        'ext_price': 344}}}},
#    {'v_id': '10275',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10275,
#      'results.@extended_price': {'59': {'product_id': 59,
#        'product_name': 'Raclette Courdavault',
#        'unit_price': 44,
#        'qty': 6,
#        'discnt': 0.05,
#        'ext_price': 250.8},
#       '24': {'product_id': 24,
#        'product_name': 'Guaraná Fantástica',
#        'unit_price': 3.6,
#        'qty': 12,
#        'discnt': 0.05,
#        'ext_price': 41.04}}}},
#    {'v_id': '10276',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10276,
#      'results.@extended_price': {'10': {'product_id': 10,
#        'product_name': 'Ikura',
#        'unit_price': 24.8,
#        'qty': 15,
#        'discnt': 0,
#        'ext_price': 372},
#       '13': {'product_id': 13,
#        'product_name': 'Konbu',
#        'unit_price': 4.8,
#        'qty': 10,
#        'discnt': 0,
#        'ext_price': 48}}}},
#    {'v_id': '10277',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10277,
#      'results.@extended_price': {'28': {'product_id': 28,
#        'product_name': 'Rössle Sauerkraut',
#        'unit_price': 36.4,
#        'qty': 20,
#        'discnt': 0,
#        'ext_price': 728},
#       '62': {'product_id': 62,
#        'product_name': 'Tarte au sucre',
#        'unit_price': 39.4,
#        'qty': 12,
#        'discnt': 0,
#        'ext_price': 472.80002}}}},
#    {'v_id': '10278',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10278,
#      'results.@extended_price': {'59': {'product_id': 59,
#        'product_name': 'Raclette Courdavault',
#        'unit_price': 44,
#        'qty': 15,
#        'discnt': 0,
#        'ext_price': 660},
#       '73': {'product_id': 73,
#        'product_name': 'Röd Kaviar',
#        'unit_price': 12,
#        'qty': 25,
#        'discnt': 0,
#        'ext_price': 300},
#       '63': {'product_id': 63,
#        'product_name': 'Vegie-spread',
#        'unit_price': 35.1,
#        'qty': 8,
#        'discnt': 0,
#        'ext_price': 280.79999},
#       '44': {'product_id': 44,
#        'product_name': 'Gula Malacca',
#        'unit_price': 15.5,
#        'qty': 16,
#        'discnt': 0,
#        'ext_price': 248}}}},
#    {'v_id': '10279',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10279,
#      'results.@extended_price': {'17': {'product_id': 17,
#        'product_name': 'Alice Mutton',
#        'unit_price': 31.2,
#        'qty': 15,
#        'discnt': 0.25,
#        'ext_price': 351}}}},
#    {'v_id': '10280',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10280,
#      'results.@extended_price': {'24': {'product_id': 24,
#        'product_name': 'Guaraná Fantástica',
#        'unit_price': 3.6,
#        'qty': 12,
#        'discnt': 0,
#        'ext_price': 43.2},
#       '75': {'product_id': 75,
#        'product_name': 'Rhönbräu Klosterbier',
#        'unit_price': 6.2,
#        'qty': 30,
#        'discnt': 0,
#        'ext_price': 186},
#       '55': {'product_id': 55,
#        'product_name': 'Pâté chinois',
#        'unit_price': 19.2,
#        'qty': 20,
#        'discnt': 0,
#        'ext_price': 384}}}},
#    {'v_id': '10281',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10281,
#      'results.@extended_price': {'24': {'product_id': 24,
#        'product_name': 'Guaraná Fantástica',
#        'unit_price': 3.6,
#        'qty': 6,
#        'discnt': 0,
#        'ext_price': 21.6},
#       '35': {'product_id': 35,
#        'product_name': 'Steeleye Stout',
#        'unit_price': 14.4,
#        'qty': 4,
#        'discnt': 0,
#        'ext_price': 57.6},
#       '19': {'product_id': 19,
#        'product_name': 'Teatime Chocolate Biscuits',
#        'unit_price': 7.3,
#        'qty': 1,
#        'discnt': 0,
#        'ext_price': 7.3}}}},
#    {'v_id': '10282',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10282,
#      'results.@extended_price': {'57': {'product_id': 57,
#        'product_name': 'Ravioli Angelo',
#        'unit_price': 15.6,
#        'qty': 2,
#        'discnt': 0,
#        'ext_price': 31.2},
#       '30': {'product_id': 30,
#        'product_name': 'Nord-Ost Matjeshering',
#        'unit_price': 20.7,
#        'qty': 6,
#        'discnt': 0,
#        'ext_price': 124.2}}}},
#    {'v_id': '10283',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10283,
#      'results.@extended_price': {'15': {'product_id': 15,
#        'product_name': 'Genen Shouyu',
#        'unit_price': 12.4,
#        'qty': 20,
#        'discnt': 0,
#        'ext_price': 248},
#       '72': {'product_id': 72,
#        'product_name': 'Mozzarella di Giovanni',
#        'unit_price': 27.8,
#        'qty': 3,
#        'discnt': 0,
#        'ext_price': 83.39999},
#       '19': {'product_id': 19,
#        'product_name': 'Teatime Chocolate Biscuits',
#        'unit_price': 7.3,
#        'qty': 18,
#        'discnt': 0,
#        'ext_price': 131.40001},
#       '60': {'product_id': 60,
#        'product_name': 'Camembert Pierrot',
#        'unit_price': 27.2,
#        'qty': 35,
#        'discnt': 0,
#        'ext_price': 952}}}},
#    {'v_id': '10284',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10284,
#      'results.@extended_price': {'27': {'product_id': 27,
#        'product_name': 'Schoggi Schokolade',
#        'unit_price': 35.1,
#        'qty': 15,
#        'discnt': 0.25,
#        'ext_price': 394.875},
#       '67': {'product_id': 67,
#        'product_name': 'Laughing Lumberjack Lager',
#        'unit_price': 11.2,
#        'qty': 5,
#        'discnt': 0.25,
#        'ext_price': 42},
#       '44': {'product_id': 44,
#        'product_name': 'Gula Malacca',
#        'unit_price': 15.5,
#        'qty': 21,
#        'discnt': 0,
#        'ext_price': 325.5},
#       '60': {'product_id': 60,
#        'product_name': 'Camembert Pierrot',
#        'unit_price': 27.2,
#        'qty': 20,
#        'discnt': 0.25,
#        'ext_price': 408}}}},
#    {'v_id': '10285',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10285,
#      'results.@extended_price': {'1': {'product_id': 1,
#        'product_name': 'Chai',
#        'unit_price': 14.4,
#        'qty': 45,
#        'discnt': 0.2,
#        'ext_price': 518.40002},
#       '53': {'product_id': 53,
#        'product_name': 'Perth Pasties',
#        'unit_price': 26.2,
#        'qty': 36,
#        'discnt': 0.2,
#        'ext_price': 754.56},
#       '40': {'product_id': 40,
#        'product_name': 'Boston Crab Meat',
#        'unit_price': 14.7,
#        'qty': 40,
#        'discnt': 0.2,
#        'ext_price': 470.39999}}}},
#    {'v_id': '10286',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10286,
#      'results.@extended_price': {'35': {'product_id': 35,
#        'product_name': 'Steeleye Stout',
#        'unit_price': 14.4,
#        'qty': 100,
#        'discnt': 0,
#        'ext_price': 1440},
#       '62': {'product_id': 62,
#        'product_name': 'Tarte au sucre',
#        'unit_price': 39.4,
#        'qty': 40,
#        'discnt': 0,
#        'ext_price': 1576}}}},
#    {'v_id': '10287',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10287,
#      'results.@extended_price': {'46': {'product_id': 46,
#        'product_name': 'Spegesild',
#        'unit_price': 9.6,
#        'qty': 15,
#        'discnt': 0.15,
#        'ext_price': 122.4},
#       '16': {'product_id': 16,
#        'product_name': 'Pavlova',
#        'unit_price': 13.9,
#        'qty': 40,
#        'discnt': 0.15,
#        'ext_price': 472.60001},
#       '34': {'product_id': 34,
#        'product_name': 'Sasquatch Ale',
#        'unit_price': 11.2,
#        'qty': 20,
#        'discnt': 0,
#        'ext_price': 224}}}},
#    {'v_id': '10288',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10288,
#      'results.@extended_price': {'54': {'product_id': 54,
#        'product_name': 'Tourtière',
#        'unit_price': 5.9,
#        'qty': 10,
#        'discnt': 0.1,
#        'ext_price': 53.1},
#       '68': {'product_id': 68,
#        'product_name': 'Scottish Longbreads',
#        'unit_price': 10,
#        'qty': 3,
#        'discnt': 0.1,
#        'ext_price': 27}}}},
#    {'v_id': '10289',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10289,
#      'results.@extended_price': {'3': {'product_id': 3,
#        'product_name': 'Aniseed Syrup',
#        'unit_price': 8,
#        'qty': 30,
#        'discnt': 0,
#        'ext_price': 240},
#       '64': {'product_id': 64,
#        'product_name': 'Wimmers gute Semmelknödel',
#        'unit_price': 26.6,
#        'qty': 9,
#        'discnt': 0,
#        'ext_price': 239.40001}}}},
#    {'v_id': '10290',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10290,
#      'results.@extended_price': {'29': {'product_id': 29,
#        'product_name': 'Thüringer Rostbratwurst',
#        'unit_price': 99,
#        'qty': 15,
#        'discnt': 0,
#        'ext_price': 1485},
#       '77': {'product_id': 77,
#        'product_name': 'Original Frankfurter grüne Soße',
#        'unit_price': 10.4,
#        'qty': 10,
#        'discnt': 0,
#        'ext_price': 104},
#       '5': {'product_id': 5,
#        'product_name': "Chef Anton's Gumbo Mix",
#        'unit_price': 17,
#        'qty': 20,
#        'discnt': 0,
#        'ext_price': 340},
#       '49': {'product_id': 49,
#        'product_name': 'Maxilaku',
#        'unit_price': 16,
#        'qty': 15,
#        'discnt': 0,
#        'ext_price': 240}}}},
#    {'v_id': '10291',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10291,
#      'results.@extended_price': {'51': {'product_id': 51,
#        'product_name': 'Manjimup Dried Apples',
#        'unit_price': 42.4,
#        'qty': 2,
#        'discnt': 0.1,
#        'ext_price': 76.32},
#       '13': {'product_id': 13,
#        'product_name': 'Konbu',
#        'unit_price': 4.8,
#        'qty': 20,
#        'discnt': 0.1,
#        'ext_price': 86.4},
#       '44': {'product_id': 44,
#        'product_name': 'Gula Malacca',
#        'unit_price': 15.5,
#        'qty': 24,
#        'discnt': 0.1,
#        'ext_price': 334.79999}}}},
#    {'v_id': '10292',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10292,
#      'results.@extended_price': {'20': {'product_id': 20,
#        'product_name': "Sir Rodney's Marmalade",
#        'unit_price': 64.8,
#        'qty': 20,
#        'discnt': 0,
#        'ext_price': 1296}}}},
#    {'v_id': '10293',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10293,
#      'results.@extended_price': {'18': {'product_id': 18,
#        'product_name': 'Carnarvon Tigers',
#        'unit_price': 50,
#        'qty': 12,
#        'discnt': 0,
#        'ext_price': 600},
#       '75': {'product_id': 75,
#        'product_name': 'Rhönbräu Klosterbier',
#        'unit_price': 6.2,
#        'qty': 6,
#        'discnt': 0,
#        'ext_price': 37.2},
#       '24': {'product_id': 24,
#        'product_name': 'Guaraná Fantástica',
#        'unit_price': 3.6,
#        'qty': 10,
#        'discnt': 0,
#        'ext_price': 36},
#       '63': {'product_id': 63,
#        'product_name': 'Vegie-spread',
#        'unit_price': 35.1,
#        'qty': 5,
#        'discnt': 0,
#        'ext_price': 175.5}}}},
#    {'v_id': '10294',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10294,
#      'results.@extended_price': {'1': {'product_id': 1,
#        'product_name': 'Chai',
#        'unit_price': 14.4,
#        'qty': 18,
#        'discnt': 0,
#        'ext_price': 259.19998},
#       '17': {'product_id': 17,
#        'product_name': 'Alice Mutton',
#        'unit_price': 31.2,
#        'qty': 15,
#        'discnt': 0,
#        'ext_price': 468},
#       '43': {'product_id': 43,
#        'product_name': 'Ipoh Coffee',
#        'unit_price': 36.8,
#        'qty': 15,
#        'discnt': 0,
#        'ext_price': 552},
#       '75': {'product_id': 75,
#        'product_name': 'Rhönbräu Klosterbier',
#        'unit_price': 6.2,
#        'qty': 6,
#        'discnt': 0,
#        'ext_price': 37.2},
#       '60': {'product_id': 60,
#        'product_name': 'Camembert Pierrot',
#        'unit_price': 27.2,
#        'qty': 21,
#        'discnt': 0,
#        'ext_price': 571.20001}}}},
#    {'v_id': '10295',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10295,
#      'results.@extended_price': {'56': {'product_id': 56,
#        'product_name': 'Gnocchi di nonna Alice',
#        'unit_price': 30.4,
#        'qty': 4,
#        'discnt': 0,
#        'ext_price': 121.6}}}},
#    {'v_id': '10296',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10296,
#      'results.@extended_price': {'16': {'product_id': 16,
#        'product_name': 'Pavlova',
#        'unit_price': 13.9,
#        'qty': 30,
#        'discnt': 0,
#        'ext_price': 417},
#       '69': {'product_id': 69,
#        'product_name': 'Gudbrandsdalsost',
#        'unit_price': 28.8,
#        'qty': 15,
#        'discnt': 0,
#        'ext_price': 432},
#       '11': {'product_id': 11,
#        'product_name': 'Queso Cabrales',
#        'unit_price': 16.8,
#        'qty': 12,
#        'discnt': 0,
#        'ext_price': 201.59999}}}},
#    {'v_id': '10297',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10297,
#      'results.@extended_price': {'72': {'product_id': 72,
#        'product_name': 'Mozzarella di Giovanni',
#        'unit_price': 27.8,
#        'qty': 20,
#        'discnt': 0,
#        'ext_price': 556},
#       '39': {'product_id': 39,
#        'product_name': 'Chartreuse verte',
#        'unit_price': 14.4,
#        'qty': 60,
#        'discnt': 0,
#        'ext_price': 864}}}},
#    {'v_id': '10298',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10298,
#      'results.@extended_price': {'59': {'product_id': 59,
#        'product_name': 'Raclette Courdavault',
#        'unit_price': 44,
#        'qty': 30,
#        'discnt': 0.25,
#        'ext_price': 990},
#       '2': {'product_id': 2,
#        'product_name': 'Chang',
#        'unit_price': 15.2,
#        'qty': 40,
#        'discnt': 0,
#        'ext_price': 608},
#       '36': {'product_id': 36,
#        'product_name': 'Inlagd Sill',
#        'unit_price': 15.2,
#        'qty': 40,
#        'discnt': 0.25,
#        'ext_price': 456},
#       '62': {'product_id': 62,
#        'product_name': 'Tarte au sucre',
#        'unit_price': 39.4,
#        'qty': 15,
#        'discnt': 0,
#        'ext_price': 591}}}},
#    {'v_id': '10299',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10299,
#      'results.@extended_price': {'70': {'product_id': 70,
#        'product_name': 'Outback Lager',
#        'unit_price': 12,
#        'qty': 20,
#        'discnt': 0,
#        'ext_price': 240},
#       '19': {'product_id': 19,
#        'product_name': 'Teatime Chocolate Biscuits',
#        'unit_price': 7.3,
#        'qty': 15,
#        'discnt': 0,
#        'ext_price': 109.5}}}},
#    {'v_id': '10300',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10300,
#      'results.@extended_price': {'66': {'product_id': 66,
#        'product_name': 'Louisiana Hot Spiced Okra',
#        'unit_price': 13.6,
#        'qty': 30,
#        'discnt': 0,
#        'ext_price': 408},
#       '68': {'product_id': 68,
#        'product_name': 'Scottish Longbreads',
#        'unit_price': 10,
#        'qty': 20,
#        'discnt': 0,
#        'ext_price': 200}}}},
#    {'v_id': '10301',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10301,
#      'results.@extended_price': {'40': {'product_id': 40,
#        'product_name': 'Boston Crab Meat',
#        'unit_price': 14.7,
#        'qty': 10,
#        'discnt': 0,
#        'ext_price': 147},
#       '56': {'product_id': 56,
#        'product_name': 'Gnocchi di nonna Alice',
#        'unit_price': 30.4,
#        'qty': 20,
#        'discnt': 0,
#        'ext_price': 608}}}},
#    {'v_id': '10302',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10302,
#      'results.@extended_price': {'17': {'product_id': 17,
#        'product_name': 'Alice Mutton',
#        'unit_price': 31.2,
#        'qty': 40,
#        'discnt': 0,
#        'ext_price': 1248},
#       '28': {'product_id': 28,
#        'product_name': 'Rössle Sauerkraut',
#        'unit_price': 36.4,
#        'qty': 28,
#        'discnt': 0,
#        'ext_price': 1019.20007},
#       '43': {'product_id': 43,
#        'product_name': 'Ipoh Coffee',
#        'unit_price': 36.8,
#        'qty': 12,
#        'discnt': 0,
#        'ext_price': 441.59998}}}},
#    {'v_id': '10303',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10303,
#      'results.@extended_price': {'65': {'product_id': 65,
#        'product_name': 'Louisiana Fiery Hot Pepper Sauce',
#        'unit_price': 16.8,
#        'qty': 30,
#        'discnt': 0.1,
#        'ext_price': 453.59998},
#       '40': {'product_id': 40,
#        'product_name': 'Boston Crab Meat',
#        'unit_price': 14.7,
#        'qty': 40,
#        'discnt': 0.1,
#        'ext_price': 529.20001},
#       '68': {'product_id': 68,
#        'product_name': 'Scottish Longbreads',
#        'unit_price': 10,
#        'qty': 15,
#        'discnt': 0.1,
#        'ext_price': 135}}}},
#    {'v_id': '10304',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10304,
#      'results.@extended_price': {'59': {'product_id': 59,
#        'product_name': 'Raclette Courdavault',
#        'unit_price': 44,
#        'qty': 10,
#        'discnt': 0,
#        'ext_price': 440},
#       '49': {'product_id': 49,
#        'product_name': 'Maxilaku',
#        'unit_price': 16,
#        'qty': 30,
#        'discnt': 0,
#        'ext_price': 480},
#       '71': {'product_id': 71,
#        'product_name': 'Flotemysost',
#        'unit_price': 17.2,
#        'qty': 2,
#        'discnt': 0,
#        'ext_price': 34.4}}}},
#    {'v_id': '10305',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10305,
#      'results.@extended_price': {'18': {'product_id': 18,
#        'product_name': 'Carnarvon Tigers',
#        'unit_price': 50,
#        'qty': 25,
#        'discnt': 0.1,
#        'ext_price': 1125},
#       '29': {'product_id': 29,
#        'product_name': 'Thüringer Rostbratwurst',
#        'unit_price': 99,
#        'qty': 25,
#        'discnt': 0.1,
#        'ext_price': 2227.5},
#       '39': {'product_id': 39,
#        'product_name': 'Chartreuse verte',
#        'unit_price': 14.4,
#        'qty': 30,
#        'discnt': 0.1,
#        'ext_price': 388.79999}}}},
#    {'v_id': '10306',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 10306,
#      'results.@extended_price': {'53': {'product_id': 53,
#        'product_name': 'Perth Pasties',
#        'unit_price': 26.2,
#        'qty': 10,
#        'discnt': 0,
#        'ext_price': 262},
#       '54': {'product_id': 54,
# ...
#     'attributes': {'results.id': 11028,
#      'results.@extended_price': {'59': {'product_id': 59,
#        'product_name': 'Raclette Courdavault',
#        'unit_price': 55,
#        'qty': 24,
#        'discnt': 0,
#        'ext_price': 1320},
#       '55': {'product_id': 55,
#        'product_name': 'Pâté chinois',
#        'unit_price': 24,
#        'qty': 35,
#        'discnt': 0,
#        'ext_price': 840}}}},
#    {'v_id': '11029',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 11029,
#      'results.@extended_price': {'56': {'product_id': 56,
#        'product_name': 'Gnocchi di nonna Alice',
#        'unit_price': 38,
#        'qty': 20,
#        'discnt': 0,
#        'ext_price': 760},
#       '63': {'product_id': 63,
#        'product_name': 'Vegie-spread',
#        'unit_price': 43.9,
#        'qty': 12,
#        'discnt': 0,
#        'ext_price': 526.80005}}}},
#    {'v_id': '11030',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 11030,
#      'results.@extended_price': {'59': {'product_id': 59,
#        'product_name': 'Raclette Courdavault',
#        'unit_price': 55,
#        'qty': 100,
#        'discnt': 0.25,
#        'ext_price': 4125},
#       '5': {'product_id': 5,
#        'product_name': "Chef Anton's Gumbo Mix",
#        'unit_price': 21.35,
#        'qty': 70,
#        'discnt': 0,
#        'ext_price': 1494.5},
#       '2': {'product_id': 2,
#        'product_name': 'Chang',
#        'unit_price': 19,
#        'qty': 100,
#        'discnt': 0.25,
#        'ext_price': 1425},
#       '29': {'product_id': 29,
#        'product_name': 'Thüringer Rostbratwurst',
#        'unit_price': 123.79,
#        'qty': 60,
#        'discnt': 0.25,
#        'ext_price': 5570.5498}}}},
#    {'v_id': '11031',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 11031,
#      'results.@extended_price': {'1': {'product_id': 1,
#        'product_name': 'Chai',
#        'unit_price': 18,
#        'qty': 45,
#        'discnt': 0,
#        'ext_price': 810},
#       '24': {'product_id': 24,
#        'product_name': 'Guaraná Fantástica',
#        'unit_price': 4.5,
#        'qty': 21,
#        'discnt': 0,
#        'ext_price': 94.5},
#       '13': {'product_id': 13,
#        'product_name': 'Konbu',
#        'unit_price': 6,
#        'qty': 80,
#        'discnt': 0,
#        'ext_price': 480},
#       '71': {'product_id': 71,
#        'product_name': 'Flotemysost',
#        'unit_price': 21.5,
#        'qty': 16,
#        'discnt': 0,
#        'ext_price': 344},
#       '64': {'product_id': 64,
#        'product_name': 'Wimmers gute Semmelknödel',
#        'unit_price': 33.25,
#        'qty': 20,
#        'discnt': 0,
#        'ext_price': 665}}}},
#    {'v_id': '11032',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 11032,
#      'results.@extended_price': {'38': {'product_id': 38,
#        'product_name': 'Côte de Blaye',
#        'unit_price': 263.5,
#        'qty': 25,
#        'discnt': 0,
#        'ext_price': 6587.5},
#       '59': {'product_id': 59,
#        'product_name': 'Raclette Courdavault',
#        'unit_price': 55,
#        'qty': 30,
#        'discnt': 0,
#        'ext_price': 1650},
#       '36': {'product_id': 36,
#        'product_name': 'Inlagd Sill',
#        'unit_price': 19,
#        'qty': 35,
#        'discnt': 0,
#        'ext_price': 665}}}},
#    {'v_id': '11033',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 11033,
#      'results.@extended_price': {'53': {'product_id': 53,
#        'product_name': 'Perth Pasties',
#        'unit_price': 32.8,
#        'qty': 70,
#        'discnt': 0.1,
#        'ext_price': 2066.3999},
#       '69': {'product_id': 69,
#        'product_name': 'Gudbrandsdalsost',
#        'unit_price': 36,
#        'qty': 36,
#        'discnt': 0.1,
#        'ext_price': 1166.40002}}}},
#    {'v_id': '11034',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 11034,
#      'results.@extended_price': {'21': {'product_id': 21,
#        'product_name': "Sir Rodney's Scones",
#        'unit_price': 10,
#        'qty': 15,
#        'discnt': 0.1,
#        'ext_price': 135},
#       '61': {'product_id': 61,
#        'product_name': "Sirop d'érable",
#        'unit_price': 28.5,
#        'qty': 6,
#        'discnt': 0,
#        'ext_price': 171},
#       '44': {'product_id': 44,
#        'product_name': 'Gula Malacca',
#        'unit_price': 19.45,
#        'qty': 12,
#        'discnt': 0,
#        'ext_price': 233.40001}}}},
#    {'v_id': '11035',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 11035,
#      'results.@extended_price': {'35': {'product_id': 35,
#        'product_name': 'Steeleye Stout',
#        'unit_price': 18,
#        'qty': 60,
#        'discnt': 0,
#        'ext_price': 1080},
#       '54': {'product_id': 54,
#        'product_name': 'Tourtière',
#        'unit_price': 7.45,
#        'qty': 10,
#        'discnt': 0,
#        'ext_price': 74.5},
#       '1': {'product_id': 1,
#        'product_name': 'Chai',
#        'unit_price': 18,
#        'qty': 10,
#        'discnt': 0,
#        'ext_price': 180},
#       '42': {'product_id': 42,
#        'product_name': 'Singaporean Hokkien Fried Mee',
#        'unit_price': 14,
#        'qty': 30,
#        'discnt': 0,
#        'ext_price': 420}}}},
#    {'v_id': '11036',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 11036,
#      'results.@extended_price': {'59': {'product_id': 59,
#        'product_name': 'Raclette Courdavault',
#        'unit_price': 55,
#        'qty': 30,
#        'discnt': 0,
#        'ext_price': 1650},
#       '13': {'product_id': 13,
#        'product_name': 'Konbu',
#        'unit_price': 6,
#        'qty': 7,
#        'discnt': 0,
#        'ext_price': 42}}}},
#    {'v_id': '11037',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 11037,
#      'results.@extended_price': {'70': {'product_id': 70,
#        'product_name': 'Outback Lager',
#        'unit_price': 15,
#        'qty': 4,
#        'discnt': 0,
#        'ext_price': 60}}}},
#    {'v_id': '11038',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 11038,
#      'results.@extended_price': {'71': {'product_id': 71,
#        'product_name': 'Flotemysost',
#        'unit_price': 21.5,
#        'qty': 30,
#        'discnt': 0,
#        'ext_price': 645},
#       '40': {'product_id': 40,
#        'product_name': 'Boston Crab Meat',
#        'unit_price': 18.4,
#        'qty': 5,
#        'discnt': 0.2,
#        'ext_price': 73.6},
#       '52': {'product_id': 52,
#        'product_name': 'Filo Mix',
#        'unit_price': 7,
#        'qty': 2,
#        'discnt': 0,
#        'ext_price': 14}}}},
#    {'v_id': '11041',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 11041,
#      'results.@extended_price': {'2': {'product_id': 2,
#        'product_name': 'Chang',
#        'unit_price': 19,
#        'qty': 30,
#        'discnt': 0.2,
#        'ext_price': 456},
#       '63': {'product_id': 63,
#        'product_name': 'Vegie-spread',
#        'unit_price': 43.9,
#        'qty': 30,
#        'discnt': 0,
#        'ext_price': 1317}}}},
#    {'v_id': '11042',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 11042,
#      'results.@extended_price': {'61': {'product_id': 61,
#        'product_name': "Sirop d'érable",
#        'unit_price': 28.5,
#        'qty': 4,
#        'discnt': 0,
#        'ext_price': 114},
#       '44': {'product_id': 44,
#        'product_name': 'Gula Malacca',
#        'unit_price': 19.45,
#        'qty': 15,
#        'discnt': 0,
#        'ext_price': 291.75}}}},
#    {'v_id': '11043',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 11043,
#      'results.@extended_price': {'11': {'product_id': 11,
#        'product_name': 'Queso Cabrales',
#        'unit_price': 21,
#        'qty': 10,
#        'discnt': 0,
#        'ext_price': 210}}}},
#    {'v_id': '11044',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 11044,
#      'results.@extended_price': {'62': {'product_id': 62,
#        'product_name': 'Tarte au sucre',
#        'unit_price': 49.3,
#        'qty': 12,
#        'discnt': 0,
#        'ext_price': 591.59998}}}},
#    {'v_id': '11046',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 11046,
#      'results.@extended_price': {'32': {'product_id': 32,
#        'product_name': 'Mascarpone Fabioli',
#        'unit_price': 32,
#        'qty': 15,
#        'discnt': 0.05,
#        'ext_price': 456},
#       '35': {'product_id': 35,
#        'product_name': 'Steeleye Stout',
#        'unit_price': 18,
#        'qty': 18,
#        'discnt': 0.05,
#        'ext_price': 307.79999},
#       '12': {'product_id': 12,
#        'product_name': 'Queso Manchego La Pastora',
#        'unit_price': 38,
#        'qty': 20,
#        'discnt': 0.05,
#        'ext_price': 722}}}},
#    {'v_id': '11047',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 11047,
#      'results.@extended_price': {'5': {'product_id': 5,
#        'product_name': "Chef Anton's Gumbo Mix",
#        'unit_price': 21.35,
#        'qty': 30,
#        'discnt': 0.25,
#        'ext_price': 480.375},
#       '1': {'product_id': 1,
#        'product_name': 'Chai',
#        'unit_price': 18,
#        'qty': 25,
#        'discnt': 0.25,
#        'ext_price': 337.5}}}},
#    {'v_id': '11048',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 11048,
#      'results.@extended_price': {'68': {'product_id': 68,
#        'product_name': 'Scottish Longbreads',
#        'unit_price': 12.5,
#        'qty': 42,
#        'discnt': 0,
#        'ext_price': 525}}}},
#    {'v_id': '11049',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 11049,
#      'results.@extended_price': {'2': {'product_id': 2,
#        'product_name': 'Chang',
#        'unit_price': 19,
#        'qty': 10,
#        'discnt': 0.2,
#        'ext_price': 152},
#       '12': {'product_id': 12,
#        'product_name': 'Queso Manchego La Pastora',
#        'unit_price': 38,
#        'qty': 4,
#        'discnt': 0.2,
#        'ext_price': 121.6}}}},
#    {'v_id': '11050',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 11050,
#      'results.@extended_price': {'76': {'product_id': 76,
#        'product_name': 'Lakkalikööri',
#        'unit_price': 18,
#        'qty': 50,
#        'discnt': 0.1,
#        'ext_price': 810}}}},
#    {'v_id': '11052',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 11052,
#      'results.@extended_price': {'61': {'product_id': 61,
#        'product_name': "Sirop d'érable",
#        'unit_price': 28.5,
#        'qty': 10,
#        'discnt': 0.2,
#        'ext_price': 228},
#       '43': {'product_id': 43,
#        'product_name': 'Ipoh Coffee',
#        'unit_price': 46,
#        'qty': 30,
#        'discnt': 0.2,
#        'ext_price': 1104}}}},
#    {'v_id': '11053',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 11053,
#      'results.@extended_price': {'18': {'product_id': 18,
#        'product_name': 'Carnarvon Tigers',
#        'unit_price': 62.5,
#        'qty': 35,
#        'discnt': 0.2,
#        'ext_price': 1750},
#       '32': {'product_id': 32,
#        'product_name': 'Mascarpone Fabioli',
#        'unit_price': 32,
#        'qty': 20,
#        'discnt': 0,
#        'ext_price': 640},
#       '64': {'product_id': 64,
#        'product_name': 'Wimmers gute Semmelknödel',
#        'unit_price': 33.25,
#        'qty': 25,
#        'discnt': 0.2,
#        'ext_price': 665}}}},
#    {'v_id': '11055',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 11055,
#      'results.@extended_price': {'24': {'product_id': 24,
#        'product_name': 'Guaraná Fantástica',
#        'unit_price': 4.5,
#        'qty': 15,
#        'discnt': 0,
#        'ext_price': 67.5},
#       '51': {'product_id': 51,
#        'product_name': 'Manjimup Dried Apples',
#        'unit_price': 53,
#        'qty': 20,
#        'discnt': 0,
#        'ext_price': 1060},
#       '25': {'product_id': 25,
#        'product_name': 'NuNuCa Nuß-Nougat-Creme',
#        'unit_price': 14,
#        'qty': 15,
#        'discnt': 0,
#        'ext_price': 210},
#       '57': {'product_id': 57,
#        'product_name': 'Ravioli Angelo',
#        'unit_price': 19.5,
#        'qty': 20,
#        'discnt': 0,
#        'ext_price': 390}}}},
#    {'v_id': '11056',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 11056,
#      'results.@extended_price': {'55': {'product_id': 55,
#        'product_name': 'Pâté chinois',
#        'unit_price': 24,
#        'qty': 35,
#        'discnt': 0,
#        'ext_price': 840},
#       '7': {'product_id': 7,
#        'product_name': "Uncle Bob's Organic Dried Pears",
#        'unit_price': 30,
#        'qty': 40,
#        'discnt': 0,
#        'ext_price': 1200},
#       '60': {'product_id': 60,
#        'product_name': 'Camembert Pierrot',
#        'unit_price': 34,
#        'qty': 50,
#        'discnt': 0,
#        'ext_price': 1700}}}},
#    {'v_id': '11057',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 11057,
#      'results.@extended_price': {'70': {'product_id': 70,
#        'product_name': 'Outback Lager',
#        'unit_price': 15,
#        'qty': 3,
#        'discnt': 0,
#        'ext_price': 45}}}},
#    {'v_id': '11060',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 11060,
#      'results.@extended_price': {'77': {'product_id': 77,
#        'product_name': 'Original Frankfurter grüne Soße',
#        'unit_price': 13,
#        'qty': 10,
#        'discnt': 0,
#        'ext_price': 130},
#       '60': {'product_id': 60,
#        'product_name': 'Camembert Pierrot',
#        'unit_price': 34,
#        'qty': 4,
#        'discnt': 0,
#        'ext_price': 136}}}},
#    {'v_id': '11063',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 11063,
#      'results.@extended_price': {'34': {'product_id': 34,
#        'product_name': 'Sasquatch Ale',
#        'unit_price': 14,
#        'qty': 30,
#        'discnt': 0,
#        'ext_price': 420},
#       '41': {'product_id': 41,
#        'product_name': "Jack's New England Clam Chowder",
#        'unit_price': 9.65,
#        'qty': 30,
#        'discnt': 0.1,
#        'ext_price': 260.54999},
#       '40': {'product_id': 40,
#        'product_name': 'Boston Crab Meat',
#        'unit_price': 18.4,
#        'qty': 40,
#        'discnt': 0.1,
#        'ext_price': 662.40002}}}},
#    {'v_id': '11064',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 11064,
#      'results.@extended_price': {'17': {'product_id': 17,
#        'product_name': 'Alice Mutton',
#        'unit_price': 39,
#        'qty': 77,
#        'discnt': 0.1,
#        'ext_price': 2702.69995},
#       '53': {'product_id': 53,
#        'product_name': 'Perth Pasties',
#        'unit_price': 32.8,
#        'qty': 25,
#        'discnt': 0.1,
#        'ext_price': 738},
#       '41': {'product_id': 41,
#        'product_name': "Jack's New England Clam Chowder",
#        'unit_price': 9.65,
#        'qty': 12,
#        'discnt': 0,
#        'ext_price': 115.8},
#       '55': {'product_id': 55,
#        'product_name': 'Pâté chinois',
#        'unit_price': 24,
#        'qty': 4,
#        'discnt': 0.1,
#        'ext_price': 86.4},
#       '68': {'product_id': 68,
#        'product_name': 'Scottish Longbreads',
#        'unit_price': 12.5,
#        'qty': 55,
#        'discnt': 0,
#        'ext_price': 687.5}}}},
#    {'v_id': '11066',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 11066,
#      'results.@extended_price': {'16': {'product_id': 16,
#        'product_name': 'Pavlova',
#        'unit_price': 17.45,
#        'qty': 3,
#        'discnt': 0,
#        'ext_price': 52.35},
#       '34': {'product_id': 34,
#        'product_name': 'Sasquatch Ale',
#        'unit_price': 14,
#        'qty': 35,
#        'discnt': 0,
#        'ext_price': 490},
#       '19': {'product_id': 19,
#        'product_name': 'Teatime Chocolate Biscuits',
#        'unit_price': 9.2,
#        'qty': 42,
#        'discnt': 0,
#        'ext_price': 386.39999}}}},
#    {'v_id': '11067',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 11067,
#      'results.@extended_price': {'41': {'product_id': 41,
#        'product_name': "Jack's New England Clam Chowder",
#        'unit_price': 9.65,
#        'qty': 9,
#        'discnt': 0,
#        'ext_price': 86.85}}}},
#    {'v_id': '11069',
#     'v_type': 'CustomerOrder',
#     'attributes': {'results.id': 11069,
#      'results.@extended_price': {'39': {'product_id': 39,
#        'product_name': 'Chartreuse verte',
#        'unit_price': 18,
#        'qty': 20,
#        'discnt': 0,
#        'ext_price': 360}}}}]}]
